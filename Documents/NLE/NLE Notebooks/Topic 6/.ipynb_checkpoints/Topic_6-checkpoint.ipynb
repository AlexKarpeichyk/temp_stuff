# %% [markdown]
# # Topic 6: Opinion Extraction

# %% [markdown]
# ## Preliminaries
# Run this cell.

# %%
import sys
sys.path.append(r'\\ad.susx.ac.uk\ITS\TeachingResources\Departments\Informatics\LanguageEngineering\resources')
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import collections
from collections import defaultdict,Counter
from itertools import zip_longest
from IPython.display import display
from random import seed
get_ipython().magic('matplotlib inline')
import random
import math
import matplotlib.pylab as pylab
# %matplotlib inline
params = {'legend.fontsize': 'large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large'}
pylab.rcParams.update(params)
from pylab import rcParams
from operator import itemgetter, attrgetter, methodcaller
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
import seaborn as sns
import csv

# %% [markdown]
# ## Overview
# In this topic you will be looking at ways to extract opinion bearing words from DVD Amazon reviews. The goal is to find words that describe particular aspects of the film being reviewed. The specific aspects of films that we will be considering are: the **plot**, the **characters**, the **cinematography** and the **dialogue**.
#
# We are, in other words, interested in finding all of those words in a review that express the reviewers opinion about one of these aspects of the film. The idea is that this will provide a fine-grained characterisation of the opinion being expressed by the author of the review. We will refer to the words we are looking for as **opinion words**, and refer to the words used for particular aspects of the review as **aspect words**.
#
# Following on from previous topic's material on dependency parsing, you will use the spaCy's output as the basis for identifying opinion words. This is based on the assumption that the opinion words we are looking for are words that occur in a sentence in the review in a particular (dependency) relationship to one of our aspect words (plot, characters, cinematography and dialogue).
#
# For example, the opinion word "*amazing*" might be found because it is used in a sentence where it is an adjective modifying the aspect word "*plot*", as in the sentence "*I thought it had an amazing plot.*".
#
# ### Exercise
# Run the cell below to set up spaCy and load in a corpus of Amazon DVD reviews.

# %%
import spacy
from sussex_nltk.corpus_readers import AmazonReviewCorpusReader

nlp = spacy.load('en')
dvd_reviews = [review for review in AmazonReviewCorpusReader().category("dvd").raw()]
print("The dvd review dataset contains {} reviews".format(len(dvd_reviews)))
parsed_reviews = [nlp(review) for review in dvd_reviews]
# Out:
# Sussex NLTK root directory is \\ad.susx.ac.uk\ITS\TeachingResources\Departments\Informatics\LanguageEngineering\resources
# The dvd review dataset contains 5491 reviews

# %% [markdown]
# ### Exercise
# We are now going to create code that finds all dependents and all heads of a list of aspect words. This code will be similar to the final exercise of the previous topic.
#
# In the blank cell below, write code that takes a set of aspect words ("*plot*","*characters*","*cinematography*", and "*dialogue*") as an argument, and produces a dictionary that maps each aspect word to a dictionary with two keys: `deps` and `heads`, where the `deps` key maps to the list of dependents of the aspect word and `heads` maps to the list of heads of the aspect word.
#
# - Note that our aspect words are nouns.
# - Note that our aspect words are not all lemmas.
#
# Display your results for dependents and heads in separate tables. For example, suppose we have the following:
# - `aspect_words` is a list of the aspect words we we interested in,
# - `all_heads` is a list of lists of the aspect word's heads, and
# - `all_dependents` is a list of lists of the aspect word's dependents
#
#
# Given this, this code will display the results:
#
# ```df_heads = pd.DataFrame(list(zip_longest(*all_heads)),
#                 columns = aspect_words).applymap(lambda x: '' if x == None else x)
# print("Heads")
# df_deps = pd.DataFrame(list(zip_longest(*all_dependents)),
#                 columns = aspect_words).applymap(lambda x: '' if x == None else x)
# display(df_heads)
# print("Dependents")
# display(df_deps)
# ```
#
# Run your code and look at the output.

# %%
aspect_words = ["plot", "characters", "cinematography", "dialogue"]
final_dict = defaultdict(lambda: defaultdict(list))

for review in parsed_reviews:
    for token in review:
        if token.pos_ == "NOUN" and token.orth_ in aspect_words:
            final_dict[token.orth_]["heads"].append(token.head.orth_)
            for child in token.children:
                final_dict[token.orth_]["deps"].append(child.orth_)
                
all_heads = [final_dict[word]["heads"] for word in aspect_words]
all_dependents = [final_dict[word]["deps"] for word in aspect_words]

df_heads = pd.DataFrame(list(zip_longest(*all_heads)), columns = aspect_words)
print("Heads")
display(df_heads)
df_deps = pd.DataFrame(list(zip_longest(*all_dependents)), columns = aspect_words)
print("Dependents")
display(df_deps)
# Out:
# Heads
#            plot  characters  cinematography    dialogue
# 0           was        talk         cramped      sounds
# 1            to          of              is        kept
# 2         holes        know              is          is
# 3            is         are              's        with
# 4            's      lumped         despite        part
# 5    characters        were             was  developing
# 6       centers         for             did        past
# 7           for          of       locations       given
# 8    irrelevant     between            make          of
# 9           was  practicing             was         was
# 10           is          of  cinematography       cover
# 11           is     writing              do       given
# 12          are          of              is       heavy
# 13           of     between              is       heavy
# 14         line        plot          handle          is
# 15           is          of            seem       seems
# 16         line        were             has      scenes
# 17           to         are       direction        need
# 18          was   presented              is          is
# 19        point          of            cast          of
# 20           is     Charlie      undermined        bite
# 21           is         are     photography          is
# 22           to   locations     interesting      wavers
# 23           is        with              is          is
# 24           is          of              of      script
# 25           is  unlikeable              to          of
# 26         lost         are           watch          by
# 27           is          of            were        have
# 28      summary  portraying              is       share
# 29          got     getting            sets          as
# ..          ...         ...             ...         ...
# 884        None  struggling            None        None
# 885        None    clicking            None        None
# 886        None     between            None        None
# 887        None         for            None        None
# 888        None        call            None        None
# 889        None       about            None        None
# 890        None          of            None        None
# 891        None         are            None        None
# 892        None        into            None        None
# 893        None     animals            None        None
# 894        None         had            None        None
# 895        None  separating            None        None
# 896        None         are            None        None
# 897        None          be            None        None
# 898        None       flesh            None        None
# 899        None          be            None        None
# 900        None     fleshed            None        None
# 901        None       about            None        None
# 902        None        film            None        None
# 903        None          of            None        None
# 904        None     fleshed            None        None
# 905        None          of            None        None
# 906        None        with            None        None
# 907        None          of            None        None
# 908        None         get            None        None
# 909        None         are            None        None
# 910        None         are            None        None
# 911        None          of            None        None
# 912        None         are            None        None
# 913        None   developed            None        None
#
# [914 rows x 4 columns]
# Dependents
#              plot     characters cinematography  dialogue
# 0             the            The            the       the
# 1             the            the            the       Her
# 2             the          other            the       The
# 3             the             or            the       the
# 4           usual            the          worst       and
# 5     predictable          other           ever      some
# 6         romance            two              ,       the
# 7             the          Black            the       bad
# 8             the              ,      beautiful       and
# 9             the           both            the    better
# 10            The              ;            the  suitable
# 11            the        several            for       all
# 12            The            key         Weapon       the
# 13            the            the              ,  terrible
# 14            and            the              F    acting
# 15     characters             or            the      rife
# 16            for           plot          awful   cliched
# 17            the            the              ,         ,
# 18            the           main       horrific       the
# 19            the            the           good        of
# 20            The            two            and       the
# 21             to            the          music   cliched
# 22            the            two           Well         ,
# 23            the            the              ,       the
# 24           keep            two           nice       The
# 25          movie           lead             as     their
# 26            the  uninteresting              :       the
# 27         itself            the      interiors  tortured
# 28            The            the              .     about
# 29            the             \n             80     their
# ...           ...            ...            ...       ...
# 1614         None          thses           None      None
# 1615         None            are           None      None
# 1616         None            the           None      None
# 1617         None            the           None      None
# 1618         None      wonderful           None      None
# 1619         None           film           None      None
# 1620         None          human           None      None
# 1621         None            the           None      None
# 1622         None            The           None      None
# 1623         None             of           None      None
# 1624         None         values           None      None
# 1625         None           five           None      None
# 1626         None          these           None      None
# 1627         None            The           None      None
# 1628         None            the           None      None
# 1629         None     villainous           None      None
# 1630         None          least           None      None
# 1631         None           some           None      None
# 1632         None              ,           None      None
# 1633         None            the           None      None
# 1634         None          other           None      None
# 1635         None           main           None      None
# 1636         None            the           None      None
# 1637         None          these           None      None
# 1638         None            the           None      None
# 1639         None          these           None      None
# 1640         None            the           None      None
# 1641         None             or           None      None
# 1642         None    stereotyped           None      None
# 1643         None            the           None      None
#
# [1644 rows x 4 columns]

# %%
# %load solutions/all_heads_and_deps
aspect_words = ["plot","characters","cinematography","dialogue"]
linked_words = defaultdict(lambda: defaultdict(list)) 
for parsed_review in parsed_reviews:
    for token in parsed_review:
        if token.pos_ == 'NOUN' and token.orth_ in aspect_words:
            linked_words[token.orth_]["heads"].append(token.head.orth_)
            for child in token.children:
                linked_words[token.orth_]["deps"].append(child.orth_)
all_heads = [linked_words[word]["heads"] for word in aspect_words]
all_dependents = [linked_words[word]["deps"] for word in aspect_words]
df_heads = pd.DataFrame(list(zip_longest(*all_heads)),
                columns = aspect_words).applymap(lambda x: '' if x == None else x)
print("Heads")
display(df_heads)
df_deps = pd.DataFrame(list(zip_longest(*all_dependents)),
                columns = aspect_words).applymap(lambda x: '' if x == None else x)
print("Dependents")
display(df_deps)

# %% [markdown]
# Our goal here is to find out what the reviewer is saying about the different aspects we are interested in.
# As you can see, not all of the words being returned are informative. In the next two exercises we look at how to (partially) address this.
#
# ### Exercise
# Make a copy of your solution to the last exercise and position it below this cell.
#
# Then adapt the code so that instead of creating lists containing just the tokens, we record the following other features:
# - For the heads:
#  - the lemma of the head,
#  - the part of speech of the head,
#  - the dependency between the head and the aspect word
# - For the dependencies:
#  - the lemma of the dependent,
#  - the port of speech of the dependent,
#  - the dependency between the dependent and the aspect word
#
# What is the point of this?
#
# The idea is that with this additional information, we will be in a better position to work out what makes heads and dependents uninteresting. For example, we might want to remove punctuation.
#
# Once you have made the necessary changes to the code, run the code on the dataset and look at the outputs to see if you can figure out ways of spotting the uninteresting entries in the table.

# %%
aspect_words = ["plot", "characters", "cinematography", "dialogue"]
final_dict = defaultdict(lambda: defaultdict(list))

for review in parsed_reviews:
    for token in review:
        if token.pos_ == "NOUN" and token.orth_ in aspect_words:
            final_dict[token.orth_]["heads"].append((token.head.orth_, token.head.lemma_, token.head.pos_, token.head.dep_))
            for child in token.children:
                final_dict[token.orth_]["deps"].append((child.orth_, child.lemma_, child.pos_, child.dep_))
                
all_heads = [final_dict[word]["heads"] for word in aspect_words]
all_dependents = [final_dict[word]["deps"] for word in aspect_words]

df_heads = pd.DataFrame(list(zip_longest(*all_heads)), columns = aspect_words)
print("Heads")
display(df_heads)
df_deps = pd.DataFrame(list(zip_longest(*all_dependents)), columns = aspect_words)
print("Dependents")
display(df_deps)
# Out:
# Heads
#                                      plot  \
# 0                   (was, be, VERB, ROOT)
# 1                     (to, to, ADP, prep)
# 2               (holes, hole, NOUN, dobj)
# 3                    (is, be, VERB, ROOT)
# 4                    ('s, be, VERB, case)
# 5     (characters, character, NOUN, pobj)
# 6           (centers, center, NOUN, ROOT)
# 7                   (for, for, ADP, prep)
# 8    (irrelevant, irrelevant, ADJ, advcl)
# 9                   (was, be, VERB, ROOT)
# 10                    (is, be, VERB, aux)
# 11                   (is, be, VERB, ROOT)
# 12                 (are, be, VERB, ccomp)
# 13                    (of, of, ADP, prep)
# 14              (line, line, NOUN, nsubj)
# 15                   (is, be, VERB, conj)
# 16               (line, line, NOUN, pobj)
# 17                    (to, to, ADP, prep)
# 18                  (was, be, VERB, ROOT)
# 19             (point, point, NOUN, pobj)
# 20                   (is, be, VERB, ROOT)
# 21                   (is, be, VERB, ROOT)
# 22                    (to, to, ADP, prep)
# 23                  (is, be, VERB, ccomp)
# 24                   (is, be, VERB, ROOT)
# 25                   (is, be, VERB, ROOT)
# 26               (lost, lose, VERB, ROOT)
# 27                   (is, be, VERB, ROOT)
# 28        (summary, summary, NOUN, nsubj)
# 29                (got, get, VERB, ccomp)
# ..                                    ...
# 884                                  None
# 885                                  None
# 886                                  None
# 887                                  None
# 888                                  None
# 889                                  None
# 890                                  None
# 891                                  None
# 892                                  None
# 893                                  None
# 894                                  None
# 895                                  None
# 896                                  None
# 897                                  None
# 898                                  None
# 899                                  None
# 900                                  None
# 901                                  None
# 902                                  None
# 903                                  None
# 904                                  None
# 905                                  None
# 906                                  None
# 907                                  None
# 908                                  None
# 909                                  None
# 910                                  None
# 911                                  None
# 912                                  None
# 913                                  None
#
#                               characters  \
# 0               (talk, talk, VERB, ROOT)
# 1                    (of, of, ADP, prep)
# 2              (know, know, VERB, relcl)
# 3                  (are, be, VERB, ROOT)
# 4            (lumped, lump, VERB, ccomp)
# 5                  (were, be, VERB, aux)
# 6                  (for, for, ADP, prep)
# 7                    (of, of, ADP, prep)
# 8          (between, between, ADP, prep)
# 9    (practicing, practice, VERB, ccomp)
# 10                   (of, of, ADP, prep)
# 11        (writing, writing, NOUN, dobj)
# 12                   (of, of, ADP, prep)
# 13         (between, between, ADP, prep)
# 14             (plot, plot, NOUN, nsubj)
# 15                   (of, of, ADP, prep)
# 16                (were, be, VERB, ROOT)
# 17                (are, be, VERB, advcl)
# 18      (presented, present, VERB, ROOT)
# 19                   (of, of, ADP, prep)
# 20      (Charlie, charlie, PROPN, nsubj)
# 21                 (are, be, VERB, ROOT)
# 22     (locations, location, NOUN, conj)
# 23               (with, with, ADP, prep)
# 24                   (of, of, ADP, prep)
# 25   (unlikeable, unlikeable, ADJ, ROOT)
# 26                 (are, be, VERB, ROOT)
# 27                   (of, of, ADP, prep)
# 28    (portraying, portray, VERB, pcomp)
# 29           (getting, get, VERB, ccomp)
# ..                                   ...
# 884  (struggling, struggle, VERB, ccomp)
# 885       (clicking, click, VERB, ccomp)
# 886        (between, between, ADP, prep)
# 887                (for, for, ADP, prep)
# 888            (call, call, VERB, relcl)
# 889            (about, about, ADP, prep)
# 890                  (of, of, ADP, prep)
# 891                (are, be, VERB, ROOT)
# 892              (into, into, ADP, prep)
# 893        (animals, animal, NOUN, dobj)
# 894             (had, have, VERB, relcl)
# 895  (separating, separate, VERB, advcl)
# 896        (are, be, VERB, advmod||conj)
# 897                 (be, be, VERB, conj)
# 898          (flesh, flesh, VERB, xcomp)
# 899                (be, be, VERB, ccomp)
# 900         (fleshed, flesh, VERB, ROOT)
# 901            (about, about, ADP, prep)
# 902             (film, film, NOUN, attr)
# 903                  (of, of, ADP, prep)
# 904         (fleshed, flesh, VERB, ROOT)
# 905                  (of, of, ADP, prep)
# 906              (with, with, ADP, prep)
# 907                  (of, of, ADP, prep)
# 908              (get, get, VERB, advcl)
# 909                (are, be, VERB, conj)
# 910               (are, be, VERB, pcomp)
# 911                  (of, of, ADP, prep)
# 912                (are, be, VERB, ROOT)
# 913     (developed, develop, VERB, ROOT)
#
#                                    cinematography  \
# 0                   (cramped, cramp, VERB, ccomp)
# 1                            (is, be, VERB, conj)
# 2                            (is, be, VERB, conj)
# 3                           ('s, be, VERB, advcl)
# 4                   (despite, despite, ADP, prep)
# 5                          (was, be, VERB, ccomp)
# 6                          (did, do, VERB, relcl)
# 7              (locations, location, NOUN, appos)
# 8                        (make, make, VERB, ROOT)
# 9                           (was, be, VERB, ROOT)
# 10   (cinematography, cinematography, NOUN, ROOT)
# 11                          (do, do, VERB, xcomp)
# 12                           (is, be, VERB, ROOT)
# 13                           (is, be, VERB, conj)
# 14                  (handle, handle, VERB, xcomp)
# 15                       (seem, seem, VERB, ROOT)
# 16                        (has, have, VERB, ROOT)
# 17             (direction, direction, NOUN, conj)
# 18                           (is, be, VERB, ROOT)
# 19                      (cast, cast, NOUN, appos)
# 20            (undermined, undermine, VERB, ROOT)
# 21    (photography, photography, NOUN, nsubjpass)
# 22          (interesting, interesting, ADJ, conj)
# 23                           (is, be, VERB, ROOT)
# 24                            (of, of, ADP, prep)
# 25                            (to, to, ADP, prep)
# 26                     (watch, watch, VERB, conj)
# 27                        (were, be, VERB, advcl)
# 28                           (is, be, VERB, ROOT)
# 29                       (sets, set, NOUN, nsubj)
# ..                                            ...
# 884                                          None
# 885                                          None
# 886                                          None
# 887                                          None
# 888                                          None
# 889                                          None
# 890                                          None
# 891                                          None
# 892                                          None
# 893                                          None
# 894                                          None
# 895                                          None
# 896                                          None
# 897                                          None
# 898                                          None
# 899                                          None
# 900                                          None
# 901                                          None
# 902                                          None
# 903                                          None
# 904                                          None
# 905                                          None
# 906                                          None
# 907                                          None
# 908                                          None
# 909                                          None
# 910                                          None
# 911                                          None
# 912                                          None
# 913                                          None
#
#                                dialogue
# 0           (sounds, sound, VERB, conj)
# 1             (kept, keep, VERB, advcl)
# 2                  (is, be, VERB, ROOT)
# 3               (with, with, ADP, prep)
# 4              (part, part, NOUN, pobj)
# 5    (developing, develop, VERB, pcomp)
# 6               (past, past, ADP, prep)
# 7              (given, give, VERB, aux)
# 8                   (of, of, ADP, prep)
# 9                 (was, be, VERB, ROOT)
# 10           (cover, cover, VERB, ROOT)
# 11             (given, give, VERB, aux)
# 12            (heavy, heavy, ADJ, amod)
# 13            (heavy, heavy, ADJ, amod)
# 14              (is, be, VERB, auxpass)
# 15         (seems, seem, VERB, auxpass)
# 16         (scenes, scene, NOUN, nsubj)
# 17              (need, ne, VERB, relcl)
# 18                 (is, be, VERB, conj)
# 19                  (of, of, ADP, prep)
# 20            (bite, bite, VERB, ccomp)
# 21                 (is, be, VERB, ROOT)
# 22         (wavers, waver, NOUN, nsubj)
# 23                 (is, be, VERB, ROOT)
# 24        (script, script, NOUN, nsubj)
# 25                  (of, of, ADP, prep)
# 26                  (by, by, ADP, prep)
# 27              (have, have, VERB, aux)
# 28            (share, share, VERB, acl)
# 29                  (as, as, ADP, prep)
# ..                                  ...
# 884                                None
# 885                                None
# 886                                None
# 887                                None
# 888                                None
# 889                                None
# 890                                None
# 891                                None
# 892                                None
# 893                                None
# 894                                None
# 895                                None
# 896                                None
# 897                                None
# 898                                None
# 899                                None
# 900                                None
# 901                                None
# 902                                None
# 903                                None
# 904                                None
# 905                                None
# 906                                None
# 907                                None
# 908                                None
# 909                                None
# 910                                None
# 911                                None
# 912                                None
# 913                                None
#
# [914 rows x 4 columns]
# Dependents
#                                        plot  \
# 0                      (the, the, DET, det)
# 1                      (the, the, DET, det)
# 2                      (the, the, DET, det)
# 3                      (the, the, DET, det)
# 4                 (usual, usual, ADJ, amod)
# 5     (predictable, predictable, ADJ, amod)
# 6        (romance, romance, NOUN, compound)
# 7                      (the, the, DET, det)
# 8                      (the, the, DET, det)
# 9                      (the, the, DET, det)
# 10                     (The, the, DET, det)
# 11                     (the, the, DET, det)
# 12                     (The, the, DET, det)
# 13                     (the, the, DET, det)
# 14                    (and, and, CCONJ, cc)
# 15      (characters, character, NOUN, conj)
# 16                    (for, for, ADP, prep)
# 17                     (the, the, DET, det)
# 18                     (the, the, DET, det)
# 19                     (the, the, DET, det)
# 20                     (The, the, DET, det)
# 21                      (to, to, ADP, prep)
# 22                     (the, the, DET, det)
# 23                     (the, the, DET, det)
# 24                  (keep, keep, VERB, acl)
# 25               (movie, movie, NOUN, poss)
# 26                     (the, the, DET, det)
# 27            (itself, -PRON-, PRON, appos)
# 28                     (The, the, DET, det)
# 29                     (the, the, DET, det)
# ...                                     ...
# 1614                                   None
# 1615                                   None
# 1616                                   None
# 1617                                   None
# 1618                                   None
# 1619                                   None
# 1620                                   None
# 1621                                   None
# 1622                                   None
# 1623                                   None
# 1624                                   None
# 1625                                   None
# 1626                                   None
# 1627                                   None
# 1628                                   None
# 1629                                   None
# 1630                                   None
# 1631                                   None
# 1632                                   None
# 1633                                   None
# 1634                                   None
# 1635                                   None
# 1636                                   None
# 1637                                   None
# 1638                                   None
# 1639                                   None
# 1640                                   None
# 1641                                   None
# 1642                                   None
# 1643                                   None
#
#                                      characters  \
# 0                          (The, the, DET, det)
# 1                          (the, the, DET, det)
# 2                     (other, other, ADJ, amod)
# 3                           (or, or, CCONJ, cc)
# 4                          (the, the, DET, det)
# 5                     (other, other, ADJ, amod)
# 6                       (two, two, NUM, nummod)
# 7                     (Black, black, ADJ, amod)
# 8                          (,, ,, PUNCT, punct)
# 9                      (both, both, DET, appos)
# 10                         (;, ;, PUNCT, punct)
# 11                (several, several, ADJ, amod)
# 12                        (key, key, ADJ, amod)
# 13                         (the, the, DET, det)
# 14                         (the, the, DET, det)
# 15                          (or, or, CCONJ, cc)
# 16                     (plot, plot, NOUN, conj)
# 17                         (the, the, DET, det)
# 18                      (main, main, ADJ, amod)
# 19                         (the, the, DET, det)
# 20                      (two, two, NUM, nummod)
# 21                         (the, the, DET, det)
# 22                      (two, two, NUM, nummod)
# 23                         (the, the, DET, det)
# 24                      (two, two, NUM, nummod)
# 25                      (lead, lead, ADJ, amod)
# 26    (uninteresting, uninteresting, ADJ, amod)
# 27                         (the, the, DET, det)
# 28                         (the, the, DET, det)
# 29                            (\n, \n, SPACE, )
# ...                                         ...
# 1614               (thses, ths, NOUN, compound)
# 1615                     (are, be, VERB, relcl)
# 1616                       (the, the, DET, det)
# 1617                       (the, the, DET, det)
# 1618          (wonderful, wonderful, ADJ, amod)
# 1619                   (film, film, NOUN, poss)
# 1620                  (human, human, ADJ, amod)
# 1621                       (the, the, DET, det)
# 1622                       (The, the, DET, det)
# 1623                        (of, of, ADP, prep)
# 1624               (values, value, NOUN, appos)
# 1625                  (five, five, NUM, nummod)
# 1626                   (these, these, DET, det)
# 1627                       (The, the, DET, det)
# 1628                       (the, the, DET, det)
# 1629        (villainous, villainous, ADJ, amod)
# 1630                (least, least, ADJ, advmod)
# 1631                     (some, some, DET, det)
# 1632                       (,, ,, PUNCT, punct)
# 1633                       (the, the, DET, det)
# 1634                  (other, other, ADJ, amod)
# 1635                    (main, main, ADJ, amod)
# 1636                       (the, the, DET, det)
# 1637                   (these, these, DET, det)
# 1638                       (the, the, DET, det)
# 1639                   (these, these, DET, det)
# 1640                       (the, the, DET, det)
# 1641                        (or, or, CCONJ, cc)
# 1642      (stereotyped, stereotype, VERB, conj)
# 1643                       (the, the, DET, det)
#
#                           cinematography                         dialogue
# 0                   (the, the, DET, det)             (the, the, DET, det)
# 1                   (the, the, DET, det)         (Her, -PRON-, ADJ, poss)
# 2                   (the, the, DET, det)             (The, the, DET, det)
# 3                   (the, the, DET, det)             (the, the, DET, det)
# 4                (worst, bad, ADJ, amod)            (and, and, CCONJ, cc)
# 5              (ever, ever, ADV, advmod)          (some, some, DET, conj)
# 6                   (,, ,, PUNCT, punct)             (the, the, DET, det)
# 7                   (the, the, DET, det)            (bad, bad, ADJ, amod)
# 8      (beautiful, beautiful, ADJ, amod)            (and, and, CCONJ, cc)
# 9                   (the, the, DET, det)        (better, good, ADJ, amod)
# 10                  (the, the, DET, det)  (suitable, suitable, ADJ, amod)
# 11                 (for, for, ADP, prep)          (all, all, ADJ, predet)
# 12        (Weapon, weapon, PROPN, appos)             (the, the, DET, det)
# 13                  (,, ,, PUNCT, punct)  (terrible, terrible, ADJ, amod)
# 14                   (F, f, PROPN, conj)     (acting, acting, NOUN, amod)
# 15                  (the, the, DET, det)         (rife, rife, ADJ, relcl)
# 16             (awful, awful, ADJ, amod)    (cliched, cliched, ADJ, amod)
# 17                  (,, ,, PUNCT, punct)             (,, ,, PUNCT, punct)
# 18      (horrific, horrific, ADJ, appos)             (the, the, DET, det)
# 19               (good, good, ADJ, amod)              (of, of, ADP, prep)
# 20                 (and, and, CCONJ, cc)             (the, the, DET, det)
# 21            (music, music, NOUN, conj)    (cliched, cliched, ADJ, amod)
# 22              (Well, well, INTJ, intj)             (,, ,, PUNCT, punct)
# 23                  (,, ,, PUNCT, punct)             (the, the, DET, det)
# 24               (nice, nice, ADJ, amod)             (The, the, DET, det)
# 25                   (as, as, ADV, prep)       (their, -PRON-, ADJ, poss)
# 26                  (:, :, PUNCT, punct)             (the, the, DET, det)
# 27    (interiors, interior, NOUN, appos)  (tortured, tortured, ADJ, amod)
# 28                  (., ., PUNCT, punct)        (about, about, ADP, prep)
# 29                   (80, 80, NUM, poss)       (their, -PRON-, ADJ, poss)
# ...                                  ...                              ...
# 1614                                None                             None
# 1615                                None                             None
# 1616                                None                             None
# 1617                                None                             None
# 1618                                None                             None
# 1619                                None                             None
# 1620                                None                             None
# 1621                                None                             None
# 1622                                None                             None
# 1623                                None                             None
# 1624                                None                             None
# 1625                                None                             None
# 1626                                None                             None
# 1627                                None                             None
# 1628                                None                             None
# 1629                                None                             None
# 1630                                None                             None
# 1631                                None                             None
# 1632                                None                             None
# 1633                                None                             None
# 1634                                None                             None
# 1635                                None                             None
# 1636                                None                             None
# 1637                                None                             None
# 1638                                None                             None
# 1639                                None                             None
# 1640                                None                             None
# 1641                                None                             None
# 1642                                None                             None
# 1643                                None                             None
#
# [1644 rows x 4 columns]

# %%
# %load solutions/all_heads_deps_features

# %% [markdown]
# ### Exercise
# We are now ready to filter out some of the entries in the table that are uninteresting.
# To do this, create the following sets:
#
# ```
# unwanted_head_deps = set()
# unwanted_head_lemmas = set()
# unwanted_head_pos = set()
# unwanted_dependent_deps = set()
# unwanted_dependent_pos = set()
# unwanted_dependent_lemmas = set()
# ```
#
# The idea is that you will manually add entries to these sets as you spot ways to eliminate uninteresting entries in the table.
#
# Undertake the following steps:
# 1. Defined an initial version of these sets based on your observations of the tables produced in the previous exercise.
# 2. Adapt the code so that these sets are used to filter out unwanted tokens before they are added to your lists of heads and dependents.
#  - one option here is to define two functions: `uninteresting_head(token)` and `uninteresting_dependent(token)`.
# 3. Run the code to see how well it has improved.
# 4. Keep adding to the sets and re-running your code until you are satisfied that you can't improve them any more.

# %%
unwanted_head_deps = {'pobj', 'attr'}
unwanted_head_lemmas = {'be', 'have', 'do'}
unwanted_head_pos = {'PROPN'}
unwanted_dependent_deps = {'det', 'predet','nummod', 'cc', 'prep', 'punct', 'case'}
unwanted_dependent_pos = {'SPACE','PROPN'}
unwanted_dependent_lemmas = {'-PRON-','do','be'}

def uninteresting_head(token):
    return token.dep_ in unwanted_head_deps or token.head.lemma_ in unwanted_head_lemmas

def uninteresting_dep(token):
    return token.dep_ in unwanted_dependent_deps or token.pos_ in unwanted_dependent_pos or token.lemma_ in unwanted_dependent_lemmas

final_dict = defaultdict(lambda: defaultdict(list))
aspect_words = ["plot", "characters", "cinematography", "dialogue"]

for review in parsed_reviews:
    for token in review:
        if token.pos_ == "NOUN" and token.orth_ in aspect_words:
            if not uninteresting_head(token):
                final_dict[token.orth_]["heads"].append((token.head.orth_, token.head.lemma_, token.head.pos_, token.head.dep_))
            for child in token.children:
                if not uninteresting_dep(token):
                    final_dict[token.orth_]["deps"].append((child.orth_, child.lemma_, child.pos_, child.dep_))
                
all_heads = [final_dict[word]["heads"] for word in aspect_words]
all_dependents = [final_dict[word]["deps"] for word in aspect_words]

df_heads = pd.DataFrame(list(zip_longest(*all_heads)), columns = aspect_words)
print("Heads")
display(df_heads)
df_deps = pd.DataFrame(list(zip_longest(*all_dependents)), columns = aspect_words)
print("Dependents")
display(df_deps)
# Out:
# Heads
#                                        plot  \
# 0                 (holes, hole, NOUN, dobj)
# 1       (characters, character, NOUN, pobj)
# 2             (centers, center, NOUN, ROOT)
# 3      (irrelevant, irrelevant, ADJ, advcl)
# 4                 (line, line, NOUN, nsubj)
# 5                  (line, line, NOUN, pobj)
# 6                (point, point, NOUN, pobj)
# 7                  (lost, lose, VERB, ROOT)
# 8           (summary, summary, NOUN, nsubj)
# 9                   (got, get, VERB, ccomp)
# 10                 (sure, sure, ADJ, advcl)
# 11               (revel, revel, VERB, ROOT)
# 12              (chunks, chunk, NOUN, dobj)
# 13               (revel, revel, VERB, ROOT)
# 14                 (wise, wise, ADJ, acomp)
# 15            (review, review, VERB, xcomp)
# 16         (behavior, behavior, NOUN, pobj)
# 17                  (gaps, gap, NOUN, attr)
# 18                  (buy, buy, VERB, relcl)
# 19            (acting, acting, NOUN, advcl)
# 20                  (get, get, VERB, ccomp)
# 21               (story, story, NOUN, ROOT)
# 22     (understood, understand, VERB, ROOT)
# 23              (twists, twist, NOUN, attr)
# 24                 (plot, plot, NOUN, ROOT)
# 25     (structuring, structure, VERB, conj)
# 26            (acting, acting, NOUN, nsubj)
# 27                 (plot, plot, NOUN, ROOT)
# 28              (twists, twist, NOUN, dobj)
# 29         (resolved, resolve, VERB, ccomp)
# ..                                      ...
# 333          (setting, setting, NOUN, ROOT)
# 334             (driven, drive, VERB, amod)
# 335            (fright, fright, NOUN, conj)
# 336               (holes, hole, NOUN, attr)
# 337  (development, development, NOUN, conj)
# 338                  (get, get, VERB, ROOT)
# 339           (shocked, shock, VERB, ccomp)
# 340               (seems, seem, VERB, ROOT)
# 341                (line, line, NOUN, conj)
# 342                (line, line, NOUN, conj)
# 343           (centers, center, NOUN, ROOT)
# 344        (dialogue, dialogue, NOUN, pobj)
# 345          (setting, setting, NOUN, ROOT)
# 346               (give, give, VERB, xcomp)
# 347         (elements, element, NOUN, conj)
# 348                (used, use, VERB, relcl)
# 349                (line, line, NOUN, pobj)
# 350          (unfolds, unfold, VERB, ccomp)
# 351                                    None
# 352                                    None
# 353                                    None
# 354                                    None
# 355                                    None
# 356                                    None
# 357                                    None
# 358                                    None
# 359                                    None
# 360                                    None
# 361                                    None
# 362                                    None
#
#                                   characters  \
# 0                   (talk, talk, VERB, ROOT)
# 1                  (know, know, VERB, relcl)
# 2                (lumped, lump, VERB, ccomp)
# 3        (practicing, practice, VERB, ccomp)
# 4             (writing, writing, NOUN, dobj)
# 5                  (plot, plot, NOUN, nsubj)
# 6           (presented, present, VERB, ROOT)
# 7           (Charlie, charlie, PROPN, nsubj)
# 8          (locations, location, NOUN, conj)
# 9        (unlikeable, unlikeable, ADJ, ROOT)
# 10        (portraying, portray, VERB, pcomp)
# 11               (getting, get, VERB, ccomp)
# 12                  (going, go, VERB, advcl)
# 13                   (get, get, VERB, relcl)
# 14                   (hit, hit, VERB, ccomp)
# 15   (grandparents, grandparent, NOUN, attr)
# 16                  (feel, feel, VERB, conj)
# 17                 (come, come, VERB, ccomp)
# 18                   (pay, pay, VERB, ccomp)
# 19               (fight, fight, VERB, ccomp)
# 20               (unique, unique, ADJ, oprd)
# 21               (running, run, VERB, relcl)
# 22              (remind, remind, VERB, ROOT)
# 23                   (buy, buy, VERB, relcl)
# 24             (speech, speech, NOUN, nsubj)
# 25           (isolate, isolate, VERB, advcl)
# 26       (characters, character, NOUN, ROOT)
# 27       (characters, character, NOUN, pobj)
# 28                (lacks, lack, VERB, ccomp)
# 29            (fleshing, flesh, VERB, pcomp)
# ..                                       ...
# 333        (overlook, overlook, VERB, xcomp)
# 334                (meet, meet, VERB, xcomp)
# 335     (understand, understand, VERB, conj)
# 336                 (knew, know, VERB, ROOT)
# 337               (story, story, NOUN, attr)
# 338        (portrayed, portray, VERB, ccomp)
# 339                 (come, come, VERB, ROOT)
# 340          (vehicles, vehicle, NOUN, conj)
# 341               (music, music, NOUN, pobj)
# 342           (changing, change, VERB, ROOT)
# 343              (taking, take, VERB, ccomp)
# 344       (supporting, support, VERB, pcomp)
# 345               (start, start, VERB, conj)
# 346              (least, least, ADJ, advmod)
# 347                  (this, this, DET, pobj)
# 348             (become, become, VERB, ROOT)
# 349    (understand, understand, VERB, xcomp)
# 350              (Mario, mario, PROPN, dobj)
# 351            (decided, decide, VERB, conj)
# 352      (struggling, struggle, VERB, ccomp)
# 353           (clicking, click, VERB, ccomp)
# 354                (call, call, VERB, relcl)
# 355            (animals, animal, NOUN, dobj)
# 356      (separating, separate, VERB, advcl)
# 357              (flesh, flesh, VERB, xcomp)
# 358             (fleshed, flesh, VERB, ROOT)
# 359                 (film, film, NOUN, attr)
# 360             (fleshed, flesh, VERB, ROOT)
# 361                  (get, get, VERB, advcl)
# 362         (developed, develop, VERB, ROOT)
#
#                                    cinematography  \
# 0                   (cramped, cramp, VERB, ccomp)
# 1              (locations, location, NOUN, appos)
# 2                        (make, make, VERB, ROOT)
# 3    (cinematography, cinematography, NOUN, ROOT)
# 4                   (handle, handle, VERB, xcomp)
# 5                        (seem, seem, VERB, ROOT)
# 6              (direction, direction, NOUN, conj)
# 7                       (cast, cast, NOUN, appos)
# 8             (undermined, undermine, VERB, ROOT)
# 9     (photography, photography, NOUN, nsubjpass)
# 10          (interesting, interesting, ADJ, conj)
# 11                     (watch, watch, VERB, conj)
# 12                       (sets, set, NOUN, nsubj)
# 13                      (using, use, VERB, advcl)
# 14                      (acting, act, VERB, conj)
# 15                (directing, direct, VERB, conj)
# 16                     (scene, scene, NOUN, pobj)
# 17                    (acting, acting, NOUN, dep)
# 18                   (writing, write, VERB, conj)
# 19                (quality, quality, NOUN, nsubj)
# 20                (composes, compose, VERB, ROOT)
# 21   (cinematography, cinematography, NOUN, ROOT)
# 22                (captures, capture, VERB, ROOT)
# 23                 (setting, setting, NOUN, nmod)
# 24                  (moments, moment, NOUN, dobj)
# 25            (storyline, storyline, NOUN, appos)
# 26   (cinematography, cinematography, NOUN, ROOT)
# 27                      (mood, mood, NOUN, nsubj)
# 28             (effective, effective, ADJ, acomp)
# 29                       (like, like, VERB, ROOT)
# ..                                            ...
# 333                                          None
# 334                                          None
# 335                                          None
# 336                                          None
# 337                                          None
# 338                                          None
# 339                                          None
# 340                                          None
# 341                                          None
# 342                                          None
# 343                                          None
# 344                                          None
# 345                                          None
# 346                                          None
# 347                                          None
# 348                                          None
# 349                                          None
# 350                                          None
# 351                                          None
# 352                                          None
# 353                                          None
# 354                                          None
# 355                                          None
# 356                                          None
# 357                                          None
# 358                                          None
# 359                                          None
# 360                                          None
# 361                                          None
# 362                                          None
#
#                                    dialogue
# 0               (sounds, sound, VERB, conj)
# 1                 (kept, keep, VERB, advcl)
# 2                  (part, part, NOUN, pobj)
# 3        (developing, develop, VERB, pcomp)
# 4                  (given, give, VERB, aux)
# 5                (cover, cover, VERB, ROOT)
# 6                  (given, give, VERB, aux)
# 7                 (heavy, heavy, ADJ, amod)
# 8                 (heavy, heavy, ADJ, amod)
# 9              (seems, seem, VERB, auxpass)
# 10             (scenes, scene, NOUN, nsubj)
# 11                  (need, ne, VERB, relcl)
# 12                (bite, bite, VERB, ccomp)
# 13             (wavers, waver, NOUN, nsubj)
# 14            (script, script, NOUN, nsubj)
# 15                (share, share, VERB, acl)
# 16   (unrealistic, unrealistic, ADJ, ccomp)
# 17   (Anachronism, anachronism, NOUN, ROOT)
# 18                 (plot, plot, NOUN, nmod)
# 19             (sounded, sound, VERB, conj)
# 20             (forced, force, VERB, ccomp)
# 21               (plots, plot, NOUN, nsubj)
# 22                 (saved, save, VERB, acl)
# 23                 (fair, fair, VERB, ROOT)
# 24             (visual, visual, ADJ, appos)
# 25        (consists, consist, VERB, advmod)
# 26             (acting, acting, NOUN, pobj)
# 27            (expect, expect, VERB, advcl)
# 28            (script, script, NOUN, nsubj)
# 29                 (tries, try, VERB, ROOT)
# ..                                      ...
# 333                                    None
# 334                                    None
# 335                                    None
# 336                                    None
# 337                                    None
# 338                                    None
# 339                                    None
# 340                                    None
# 341                                    None
# 342                                    None
# 343                                    None
# 344                                    None
# 345                                    None
# 346                                    None
# 347                                    None
# 348                                    None
# 349                                    None
# 350                                    None
# 351                                    None
# 352                                    None
# 353                                    None
# 354                                    None
# 355                                    None
# 356                                    None
# 357                                    None
# 358                                    None
# 359                                    None
# 360                                    None
# 361                                    None
# 362                                    None
#
# [363 rows x 4 columns]
# Dependents
#                                        plot  \
# 0                      (the, the, DET, det)
# 1                      (the, the, DET, det)
# 2                      (the, the, DET, det)
# 3                      (the, the, DET, det)
# 4                 (usual, usual, ADJ, amod)
# 5     (predictable, predictable, ADJ, amod)
# 6        (romance, romance, NOUN, compound)
# 7                      (the, the, DET, det)
# 8                      (the, the, DET, det)
# 9                      (the, the, DET, det)
# 10                     (The, the, DET, det)
# 11                     (the, the, DET, det)
# 12                     (The, the, DET, det)
# 13                     (the, the, DET, det)
# 14                    (and, and, CCONJ, cc)
# 15      (characters, character, NOUN, conj)
# 16                    (for, for, ADP, prep)
# 17                     (the, the, DET, det)
# 18                     (the, the, DET, det)
# 19                     (the, the, DET, det)
# 20                     (The, the, DET, det)
# 21                      (to, to, ADP, prep)
# 22                     (the, the, DET, det)
# 23                     (the, the, DET, det)
# 24                  (keep, keep, VERB, acl)
# 25               (movie, movie, NOUN, poss)
# 26                     (the, the, DET, det)
# 27            (itself, -PRON-, PRON, appos)
# 28                     (The, the, DET, det)
# 29                     (the, the, DET, det)
# ...                                     ...
# 1614                                   None
# 1615                                   None
# 1616                                   None
# 1617                                   None
# 1618                                   None
# 1619                                   None
# 1620                                   None
# 1621                                   None
# 1622                                   None
# 1623                                   None
# 1624                                   None
# 1625                                   None
# 1626                                   None
# 1627                                   None
# 1628                                   None
# 1629                                   None
# 1630                                   None
# 1631                                   None
# 1632                                   None
# 1633                                   None
# 1634                                   None
# 1635                                   None
# 1636                                   None
# 1637                                   None
# 1638                                   None
# 1639                                   None
# 1640                                   None
# 1641                                   None
# 1642                                   None
# 1643                                   None
#
#                                      characters  \
# 0                          (The, the, DET, det)
# 1                          (the, the, DET, det)
# 2                     (other, other, ADJ, amod)
# 3                           (or, or, CCONJ, cc)
# 4                          (the, the, DET, det)
# 5                     (other, other, ADJ, amod)
# 6                       (two, two, NUM, nummod)
# 7                     (Black, black, ADJ, amod)
# 8                          (,, ,, PUNCT, punct)
# 9                      (both, both, DET, appos)
# 10                         (;, ;, PUNCT, punct)
# 11                (several, several, ADJ, amod)
# 12                        (key, key, ADJ, amod)
# 13                         (the, the, DET, det)
# 14                         (the, the, DET, det)
# 15                          (or, or, CCONJ, cc)
# 16                     (plot, plot, NOUN, conj)
# 17                         (the, the, DET, det)
# 18                      (main, main, ADJ, amod)
# 19                         (the, the, DET, det)
# 20                      (two, two, NUM, nummod)
# 21                         (the, the, DET, det)
# 22                      (two, two, NUM, nummod)
# 23                         (the, the, DET, det)
# 24                      (two, two, NUM, nummod)
# 25                      (lead, lead, ADJ, amod)
# 26    (uninteresting, uninteresting, ADJ, amod)
# 27                         (the, the, DET, det)
# 28                         (the, the, DET, det)
# 29                            (\n, \n, SPACE, )
# ...                                         ...
# 1614               (thses, ths, NOUN, compound)
# 1615                     (are, be, VERB, relcl)
# 1616                       (the, the, DET, det)
# 1617                       (the, the, DET, det)
# 1618          (wonderful, wonderful, ADJ, amod)
# 1619                   (film, film, NOUN, poss)
# 1620                  (human, human, ADJ, amod)
# 1621                       (the, the, DET, det)
# 1622                       (The, the, DET, det)
# 1623                        (of, of, ADP, prep)
# 1624               (values, value, NOUN, appos)
# 1625                  (five, five, NUM, nummod)
# 1626                   (these, these, DET, det)
# 1627                       (The, the, DET, det)
# 1628                       (the, the, DET, det)
# 1629        (villainous, villainous, ADJ, amod)
# 1630                (least, least, ADJ, advmod)
# 1631                     (some, some, DET, det)
# 1632                       (,, ,, PUNCT, punct)
# 1633                       (the, the, DET, det)
# 1634                  (other, other, ADJ, amod)
# 1635                    (main, main, ADJ, amod)
# 1636                       (the, the, DET, det)
# 1637                   (these, these, DET, det)
# 1638                       (the, the, DET, det)
# 1639                   (these, these, DET, det)
# 1640                       (the, the, DET, det)
# 1641                        (or, or, CCONJ, cc)
# 1642      (stereotyped, stereotype, VERB, conj)
# 1643                       (the, the, DET, det)
#
#                           cinematography                         dialogue
# 0                   (the, the, DET, det)             (the, the, DET, det)
# 1                   (the, the, DET, det)         (Her, -PRON-, ADJ, poss)
# 2                   (the, the, DET, det)             (The, the, DET, det)
# 3                   (the, the, DET, det)             (the, the, DET, det)
# 4                (worst, bad, ADJ, amod)            (and, and, CCONJ, cc)
# 5              (ever, ever, ADV, advmod)          (some, some, DET, conj)
# 6                   (,, ,, PUNCT, punct)             (the, the, DET, det)
# 7                   (the, the, DET, det)            (bad, bad, ADJ, amod)
# 8      (beautiful, beautiful, ADJ, amod)            (and, and, CCONJ, cc)
# 9                   (the, the, DET, det)        (better, good, ADJ, amod)
# 10                  (the, the, DET, det)  (suitable, suitable, ADJ, amod)
# 11                 (for, for, ADP, prep)          (all, all, ADJ, predet)
# 12        (Weapon, weapon, PROPN, appos)             (the, the, DET, det)
# 13                  (,, ,, PUNCT, punct)  (terrible, terrible, ADJ, amod)
# 14                   (F, f, PROPN, conj)     (acting, acting, NOUN, amod)
# 15                  (the, the, DET, det)         (rife, rife, ADJ, relcl)
# 16             (awful, awful, ADJ, amod)    (cliched, cliched, ADJ, amod)
# 17                  (,, ,, PUNCT, punct)             (,, ,, PUNCT, punct)
# 18      (horrific, horrific, ADJ, appos)             (the, the, DET, det)
# 19               (good, good, ADJ, amod)              (of, of, ADP, prep)
# 20                 (and, and, CCONJ, cc)             (the, the, DET, det)
# 21            (music, music, NOUN, conj)    (cliched, cliched, ADJ, amod)
# 22              (Well, well, INTJ, intj)             (,, ,, PUNCT, punct)
# 23                  (,, ,, PUNCT, punct)             (the, the, DET, det)
# 24               (nice, nice, ADJ, amod)             (The, the, DET, det)
# 25                   (as, as, ADV, prep)       (their, -PRON-, ADJ, poss)
# 26                  (:, :, PUNCT, punct)             (the, the, DET, det)
# 27    (interiors, interior, NOUN, appos)  (tortured, tortured, ADJ, amod)
# 28                  (., ., PUNCT, punct)        (about, about, ADP, prep)
# 29                   (80, 80, NUM, poss)       (their, -PRON-, ADJ, poss)
# ...                                  ...                              ...
# 1614                                None                             None
# 1615                                None                             None
# 1616                                None                             None
# 1617                                None                             None
# 1618                                None                             None
# 1619                                None                             None
# 1620                                None                             None
# 1621                                None                             None
# 1622                                None                             None
# 1623                                None                             None
# 1624                                None                             None
# 1625                                None                             None
# 1626                                None                             None
# 1627                                None                             None
# 1628                                None                             None
# 1629                                None                             None
# 1630                                None                             None
# 1631                                None                             None
# 1632                                None                             None
# 1633                                None                             None
# 1634                                None                             None
# 1635                                None                             None
# 1636                                None                             None
# 1637                                None                             None
# 1638                                None                             None
# 1639                                None                             None
# 1640                                None                             None
# 1641                                None                             None
# 1642                                None                             None
# 1643                                None                             None
#
# [1644 rows x 4 columns]

# %%
# %load solutions/filtered_heads_deps
unwanted_head_deps = {'pobj', 'attr', 'pobj'}
unwanted_head_lemmas = {'be','have','do'}
unwanted_head_pos = {'PROPN'}
unwanted_dependent_deps = {'det', 'predet','nummod', 'cc', 'prep', 'punct', 'case'}
unwanted_dependent_pos = {'SPACE','PROPN'}
unwanted_dependent_lemmas = {'-PRON-','do','be'}

def uninteresting_head(token):
    return token.dep_ in unwanted_head_deps or token.head.lemma_ in unwanted_head_lemmas

def uninteresting_dep(token):
    return token.dep_ in unwanted_dependent_deps or token.pos_ in unwanted_dependent_pos or token.lemma_ in unwanted_dependent_lemmas

aspect_words = ["plot","characters","cinematography","dialogue"]
linked_words = defaultdict(lambda: defaultdict(list)) 
for parsed_review in parsed_reviews:
    for token in parsed_review:
        if token.pos_ == 'NOUN' and token.orth_ in aspect_words:
            if not uninteresting_head(token): 
                linked_words[token.orth_]["heads"].append((token.head.orth_,token.head.pos_,token.dep_,token.head.lemma_))
            for child in token.children:
                if not uninteresting_dep(child):
                    linked_words[token.orth_]["deps"].append((child.orth_,child.pos_,child.dep_,child.lemma_))
all_heads = [linked_words[word]["heads"] for word in aspect_words]
all_dependents = [linked_words[word]["deps"] for word in aspect_words]
df_heads = pd.DataFrame(list(zip_longest(*all_heads)),
                columns = aspect_words).applymap(lambda x: '' if x == None else x)
print("Heads")
display(df_heads)
df_deps = pd.DataFrame(list(zip_longest(*all_dependents)),
                columns = aspect_words).applymap(lambda x: '' if x == None else x)
print("Dependents")
display(df_deps)

# %% [markdown]
# ## Opinion extractor
# Over the remaining exercises in this notebook, we are now going to create and subsequently refine a function called `opinion_extractor`.
#
# `opinion_extractor` takes two arguments:
# - `aspect_token`: an aspect token, such as "*plot*", "*characters*", "*cinematography*" and "*dialogue*".
# - `parsed_sentence`: a parsed sentence
# The output should be a list of extracted opinions, i.e. a list of tokens that tell us something about what the reviewer is saying (in `parsed_sentence`) about `aspect_token`.
#
# ### Exercise
# To begin, in the cell below, complete an initial verison of the function `opinion_extractor` that returns a list of all dependents of the aspect token.
# - This list will be empty when there are no opinions relating `aspect_token` to extract in `parsed_sentence`.

# %%
def opinion_extractor(aspect_token,parsed_sentence):
    opinions = list()
    for token in parsed_sentence:
        if token.pos_ == "NOUN" and token.orth_ == aspect_token:
            for child in token.children:
                opinions.append(child.orth_)
    return opinions

def show_results(results,aspect_word):
    print("Results for aspect word '{}'\n".format(aspect_word))
    for word,sent,opinions in results:
        if word == aspect_word:
            print("Sentence:\n\t{}".format(sent))
            print("Opinion of '{0}':\n\t '{1}'".format(aspect_word,"', '".join(opinions)))
            print("\n")

aspect_words = ["plot","characters","cinematography","dialogue"]
results = [] 
for parsed_review in parsed_reviews:
    for sentence in parsed_review.sents:
        for aspect_token in aspect_words:
            opinions = opinion_extractor(aspect_token,sentence)
            if opinions:
                results.append((aspect_token,sentence.orth_,opinions))

show_results(results,"plot")
show_results(results,"characters")
show_results(results,"cinematography")
show_results(results,"dialogue")
# Out:
# Results for aspect word 'plot'
#
# Sentence:
# 	However, the plot was predictable.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	I'm still not sure what Jody Foster's character brings to the plot.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	Furthermore, the plot is so predictable that it made the movie drag.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	& then Owen Wilson's character fall in love with Rachel's McAdams character and well, that's the usual predictable romance plot.
# Opinion of 'plot':
# 	 'the', 'usual', 'predictable', 'romance'
#
#
# Sentence:
# 	This movie didn't do anything for me...Didn't care for the characters or the plot.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	Not enough weirdness, tried too much for the plot.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	Given my dislike of how the Japanese culture was handled in this film, it left me finding the plot irrelevant.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot was OK but it would have been much better if they had either stuck to a more authentic representation of Japanese culture or kept the story in the states.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	The performances are thin and uneven, the plot is inconsistent, and the dialogue sounds like it was pulled from fortune cookies made by the cast of Friends.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot is uninvolving and incoherent, the cinematography is cramped and completely lacking in style, the music is weak during a time that spawned so many memorable soundtracks and the direction lacks any focus whatsoever.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	Although this movie wanted to be in the same race and quality of the movie CLUE, it fails to realize that the plot and characters are incredibly riculous and not funny ha ha but funny stupid.
# Opinion of 'plot':
# 	 'the', 'and', 'characters'
#
#
# Sentence:
# 	I usually enjoy movies with this breaking-away-from-boredom type of plot for example...
# Opinion of 'plot':
# 	 'for'
#
#
# Sentence:
# 	The acting is horrible, the plot is horrible, the filming is horrible...  Everything is horrible!  I was hopeful because of Snipes, which is why I rented it despite not ever seeing the movie anywhere before in the theaters.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	It means nothing to the plot, and is the ultimate contrivance.)
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	Not only was the dialogue of the film trite and the plot much like a pornographic after school special, but the movie unfortunately reinforces a worldview which anti-homosexual groups been touting for years--If you're thinking turning your female frienship into a relationship, don't.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot to this movie or so called sequal is horrible.
# Opinion of 'plot':
# 	 'The', 'to'
#
#
# Sentence:
# 	Basically the plot is Tucker runs around dodging bullets and calling everyone a name.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The film is not interested in adding new elements to the plot to keep things at least appearing fresh.
# Opinion of 'plot':
# 	 'the', 'keep'
#
#
# Sentence:
# 	The problem is, the movie's plot is a slow-moving, wasted opportunity.
# Opinion of 'plot':
# 	 'movie'
#
#
# Sentence:
# 	The first is the plot itself.
# Opinion of 'plot':
# 	 'the', 'itself'
#
#
# Sentence:
# 	The plot is a by-the-book "believe in your dreams" story with really lame dialog, but its development is intercut with extended dancing sequences that are so long and frequent that at times it felt like I was watching an abstract silent film.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	In one part, the plot lost some continuity and needed reviewing to get to grips with what had happened.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot for the movie is actually surprisingly straightforward once you cut away all the filler, but that's the biggest problem.
# Opinion of 'plot':
# 	 'The', 'for'
#
#
# Sentence:
# 	The trouble is, this movie hasn't got any plot to distract you from how redundant the visual style is.
# Opinion of 'plot':
# 	 'any'
#
#
# Sentence:
# 	There's nothing inherently wrong with any of his tactics, but they're hopelessly driven in to the ground, as we see fast-motion a thousand times, quick-cut montages a million times and plenty of wonky camera-attached-to-the-actor junk, and they are, again, impossible not to notice cause the plot sure ain't drawing me in.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	However, the plot and message of this film revel in hopelessness, and debase every aspect of lower income, urban people.
# Opinion of 'plot':
# 	 'the', 'and', 'message', 'of'
#
#
# Sentence:
# 	Pollack takes all that intricately woven little Grisham-plot and barfs big ugly chunks of it up on the screen.
# Opinion of 'plot':
# 	 'Grisham', '-', 'and', 'barfs'
#
#
# Sentence:
# 	I didn't even mind the obvious holes in the plot, such as...why do these characters not have credit cards or cell phones?
# Opinion of 'plot':
# 	 'the', ',', 'as'
#
#
# Sentence:
# 	The main plot is very thin (a CIA agent is ordered to kill an oil prince, gets caught and then warns the prince (why?)) and therefore some elements were added to make the movie more interesting.
# Opinion of 'plot':
# 	 'The', 'main'
#
#
# Sentence:
# 	However, the plot and message of this film revel in hopelessness, and debase every aspect of lower income, urban people.
# Opinion of 'plot':
# 	 'the', 'and', 'message', 'of'
#
#
# Sentence:
# 	With their childest voices, they shouldn't be used as a main plot of the story
# Opinion of 'plot':
# 	 'a', 'main', 'of'
#
#
# Sentence:
# 	As far as the movie is concerned, the plot is unoriginal and not particularly engaging.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot is that old but reliable one about a man posing as a prisoner so he can go "undercover" and solve a crime.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	What Dylan did to counter the similarity between Redman/Method Man was bring in obscure secondary characters that added nothing to the flimsy plot or helped us feel emotion for our two main characters.
# Opinion of 'plot':
# 	 'the', 'flimsy', 'or', 'helped'
#
#
# Sentence:
# 	I'm not going to review the plot because it's been done by several reviewers already.
# Opinion of 'plot':
# 	 'the', 'done'
#
#
# Sentence:
# 	Instead we have additions of Colonel Hart's unexplained behavior, an mass tunnel escape plot, sabotage and the German Commandant's attempt to befriend the American lawyer as superfluous baggage.
# Opinion of 'plot':
# 	 'an', 'escape', ',', 'sabotage'
#
#
# Sentence:
# 	This was such a contrived movie that had a simple plot that went nowhere.
# Opinion of 'plot':
# 	 'a', 'simple', 'went'
#
#
# Sentence:
# 	They were incomplete and contributed little, if anything, to the plot.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	Now with regards to the plot of this film there were enormous holes, which perhaps could be rectified by reading the book.
# Opinion of 'plot':
# 	 'the', 'of'
#
#
# Sentence:
# 	Aren't we sick of all the crowd pleasing PG-13 shows which are neither sexy or action packed - most of all with hardly a plot?
# Opinion of 'plot':
# 	 'a'
#
#
# Sentence:
# 	The similarities of these 2 movies are so prominent that it would actually be a waste of time and money to buy both - same characters, same plot only in a different setting.
# Opinion of 'plot':
# 	 'same'
#
#
# Sentence:
# 	The movie wasn't funny (which is sad to say when one of my favorite comedic actresses, Carol Kane, couldn't even elicit a smile out of me), the plot was full of holes, and the writing seemed very rushed and contrived.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The special effects are a bit cheesy, you can see the wires pulling the torpedos and you can tell that they used scaled model ships...but if you overlook those items, you get fine acting and a good plot with plenty of
# action
# Opinion of 'plot':
# 	 'a', 'good', 'with'
#
#
# Sentence:
# 	It is one of those ones that you keep watching because you think it may get better and it never does... stupid plot - too many holes and stupid ending.
# Opinion of 'plot':
# 	 'stupid', 'ending'
#
#
# Sentence:
# 	The plot was..well..stupid and the atmosphere of the movie was pretty much non-existent.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	The entire plot is self-serving, shallow, and unrealistic.
# Opinion of 'plot':
# 	 'The', 'entire'
#
#
# Sentence:
# 	I understood the plot, and enjoyed some of the thoughts raised near the end, but overall was bored silly by stilted, pointless dialogue.
# Opinion of 'plot':
# 	 'the', ','
#
#
# Sentence:
# 	A plot that, as rendered in the film (whether it's the fault of the screenwriter or the editor, I can't be sure), never quite follows through on any of its elements.
# Opinion of 'plot':
# 	 'A', 'that', ''s', '.'
#
#
# Sentence:
# 	The plot is stupid, the characters are dull and insipid, and the whole movie leaves you asking, as the credits run, "So What?" Don't waste your money!
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	The screenplay is so lazy it can't even be bothered to connect half the characters to the plot, the photography is bright and glossy, which is at odds with what's supposed to be a dark story, while nothing in the direction adds any atmosphere at all.
# Opinion of 'plot':
# 	 'the', ','
#
#
# Sentence:
# 	No thought has gone in to developing themes or structuring the plot because no one here is talented enough to give this movie any depth beyond having D'Errico running around in a variety of tight vests.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	In short, the acting and the plot are average (nothing great), while the dialogues are way below average.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	This movie is the kind where you will see a remotely interesting twist in the plot about 3/4's of the way in and you'll think, "wow I wonder where the story will go next".
# Opinion of 'plot':
# 	 'the', ''s'
#
#
# Sentence:
# 	If you've seen that version, you probably still can't get the final revelation out of your head, but the film had plenty more to offer than that, playing with chronology, subverting the usual cliches of its 'Lady Vanishes' plot (the hero wants to know what happened to his missing lover far more than he wants her to be alive) and throwing in some excellent characterization.
# Opinion of 'plot':
# 	 'its', 'Vanishes', '(', 'wants'
#
#
# Sentence:
# 	The plot, the "humor," the dialogues, and the music are way beyond "below average."
# Opinion of 'plot':
# 	 'The', ',', 'humor'
#
#
# Sentence:
# 	I found the plot to be a little farfetched
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	A kid chasing a ticket through a train,
#
# A kid chasing a ticket over the roof of a train,
#
# A ticket making its way through the forest -- Rube Goldberg style -- back to the train,
#
# (Forty minutes into this movie and one girl's train ticket is the star of the show!)
#
# OK, the ticket sub plot is resolved and we have...
#
# A train sliding out of control on the ice,
#
# A train trying to outrun cracks on the ice,
#
# A train going full throttle out of control and racing up and down mountain valleys like a roller coaster (fans of the "coaster tycoon" series of computer games will feel right at home) until finally it arrives at the North Pole.
# Opinion of 'plot':
# 	 'the', 'sub'
#
#
# Sentence:
# 	The plot is stupid, the characters are dull and insipid, and the whole movie leaves you asking, as the credits run, "So What?" Don't waste your money!
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	The plot, what there is of it, deals with police corruption, and features a major twist near the end that takes the punch out of the story and doesn't make any sense---but by that time you've stopped caring.
# Opinion of 'plot':
# 	 'The', ','
#
#
# Sentence:
# 	The basic plot of the movie is that life sucks (yeah thats it).
# Opinion of 'plot':
# 	 'The', 'basic', 'of'
#
#
# Sentence:
# 	The plot is lame and I am sorry I spent the money on it.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	The plot involves a fire 20 years ago, when Daryl Hannah was eight, a fire that killed her artist father and purportedly destroyed a large number of his paintings.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	Unfortunately, the plot involves many elements that simply don't make sense.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	I won't go into detail, but Roger Ebert does a good job of listing four different major things that make the plot completely unbelievable.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	This movie could have been a fairly good romantic thriller if they had fixed the plot and not tried to be a comedy.
# Opinion of 'plot':
# 	 'the', 'and'
#
#
# Sentence:
# 	But the dumb plot and the unfunny attempts at comedy make it a complete waste of time.
# Opinion of 'plot':
# 	 'the', 'dumb', 'and', 'attempts'
#
#
# Sentence:
# 	If the plot doesn't seem stupid enough, it needs Ghosts to power it.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	Eraser has a few scenes that will keep your attention, but overall the movie displayed poor acting, stunts that are impossible and a mediocre plot.
# Opinion of 'plot':
# 	 'a', 'mediocre'
#
#
# Sentence:
# 	If you've seen that version, you probably still can't get the final revelation out of your head, but the film had plenty more to offer than that, playing with chronology, subverting the usual cliches of its 'Lady Vanishes' plot (the hero wants to know what happened to his missing lover far more than he wants her to be alive) and throwing in some excellent characterization.
# Opinion of 'plot':
# 	 'its', 'Vanishes', '(', 'wants'
#
#
# Sentence:
# 	The plot revolves around two "losers in love" who are unappealing both in looks and personality.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	Very predictable plot from beginning to end.
# Opinion of 'plot':
# 	 'Very', 'predictable', 'from', '.'
#
#
# Sentence:
# 	Anachronism, bad dialogue, bad plot and plain old bad acting plague this "sequel".
# Opinion of 'plot':
# 	 'bad', 'and', 'plague', 'sequel'
#
#
# Sentence:
# 	I was very bored with this movie and found the plot to be very insulting.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot and dialogue dehumanizies and insults many.
# Opinion of 'plot':
# 	 'and', 'dialogue'
#
#
# Sentence:
# 	Buy somthing that has a good plot.
# Opinion of 'plot':
# 	 'a', 'good'
#
#
# Sentence:
# 	The Mummy Returns" abandons the characters, and the plot is utilized simply as a flimsy clothesline for action and F/X sequences.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	One of the worst movies i've ever seen, no real plot and acting is as bad as it can get.
# Opinion of 'plot':
# 	 'no', 'real', 'and', 'acting'
#
#
# Sentence:
# 	If you're reviewing the DVD, speak to the qualities (or lack thereof) of the audio and video; mention your opinions of the plot, acting, etc.
# Opinion of 'plot':
# 	 'the', ','
#
#
# Sentence:
# 	The plot moves along nicely and creates some definite tension and suspense.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	You can see the few twists and turns in the plot coming miles before they happen.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	Can you really carry 2 hours with this single plot?
# Opinion of 'plot':
# 	 'this', 'single'
#
#
# Sentence:
# 	The cast is good, but the plot stinks!
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot turns out to be terrible and the idea of where the wolves came from and where they are going is underdeveloped and disappointing.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	What looks like a good movie to watch quickly turns into disappointment. Whilst you expect some plot to come together (at least on first viewing)
# Opinion of 'plot':
# 	 'some'
#
#
# Sentence:
# 	The plot is complicated and the noise in the background adds to the disorientation which is done on purpose.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	I didn't even mind the obvious holes in the plot, such as...why do these characters not have credit cards or cell phones?
# Opinion of 'plot':
# 	 'the', ',', 'as'
#
#
# Sentence:
# 	Besides the sex scenes, language, pill popping and other thematic elements that are left out, important details to the plot are also missing.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The main plot is very thin (a CIA agent is ordered to kill an oil prince, gets caught and then warns the prince (why?)) and therefore some elements were added to make the movie more interesting.
# Opinion of 'plot':
# 	 'The', 'main'
#
#
# Sentence:
# 	It's the way the story is told - its ham-fisted dialogue and plot, its forced obscenity at every turn - that reveals its teen sensibilities.
# Opinion of 'plot':
# 	 ','
#
#
# Sentence:
# 	I'll cut to the meta-chase since plot and story have already been well outlined in previous reviews...
# Opinion of 'plot':
# 	 'and', 'story'
#
#
# Sentence:
# 	But the plot was lame & slow.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	But I just had to shut it off - there was nothing advancing the plot or the characters, so I just didn't care how it ended.
#
# 1 star for the plot, 1.5 stars for the screenplay, 2 stars for the singing
# Opinion of 'plot':
# 	 'the', 'or', 'characters', 'the', ',', 'stars'
#
#
# Sentence:
# 	The plot was butchered, the characters twisted, the story ruined, a pure agony.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	The plot is rather unbelievable, naming the fact that all three main characters are leaders in their field.... successful author, high-ranking network producer, top-rate doctor.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	This series might be considered a classic if watched by a 12-year-old, but adults will see though the indistinct plot and characters.
# Opinion of 'plot':
# 	 'the', 'indistinct', 'and', 'characters'
#
#
# Sentence:
# 	Most of the plot's famous "unpleasantness" is just tacked on to the main story, and is of no significance.
# Opinion of 'plot':
# 	 'the', ''s'
#
#
# Sentence:
# 	Finally the main part of the plot begins, with Natalie just as discontented, despite being married to a wealthy and quirky-but-ultimately-nice guy (Alan Rickman, for whose sake I watched this film at all--not worth it), and with her brother seemingly happy with his life, but somehow still willing to be drawn into a sexual relationship with his sister.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot just wanders aimlessly through an only semi-believable situation, scattering out the occasional pebble of human misery with its slogging feet.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	Is it me or them that has totally lost the plot of what movies are supposed to be all about?
# Opinion of 'plot':
# 	 'the', 'of'
#
#
# Sentence:
# 	The plot was adequate.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	I just can't get over how profoundly corny and simple the plot and effects are, it's downright insulting to the human brain.
# Opinion of 'plot':
# 	 'the', 'and', 'effects'
#
#
# Sentence:
# 	Before I hit this too harshly, this film was intended to be a trifle, the kind of movie that has bright colors and light plot for a hot summer day that sizzles.
# Opinion of 'plot':
# 	 'light', 'for'
#
#
# Sentence:
# 	The plot of the story was ruined by the immorality and language.
# Opinion of 'plot':
# 	 'The', 'of'
#
#
# Sentence:
# 	It is possible to have something beautiful and clean where when you finish you feel that you have experienced something encouraging and uplifting.   Dying Young and the plot of sickness and someone caring is beautiful.
# Opinion of 'plot':
# 	 'the', 'of', 'is'
#
#
# Sentence:
# 	Really... as in unwatchable (other than the relatively entertaining animated opening credits.) Painfully unfunny slapstick routines, actors seemingly reading their lines off of cue cards, and no plot to speak of.
# Opinion of 'plot':
# 	 'no', 'speak'
#
#
# Sentence:
# 	I honestly don't even know the plot of this movie, and I'm not kidding.
# Opinion of 'plot':
# 	 'the', 'of'
#
#
# Sentence:
# 	If you want an idea for a good movie, read the back of this DVD case, and follow that plot, as the director sure steered clear of it.
# Opinion of 'plot':
# 	 'that', ','
#
#
# Sentence:
# 	To date, the two credited writers have yet to muster up a single true hit, and one gets the sense that a more competent writing team would have taken a better direction with the plot and have not wasted the obvious talent that Ms. Lohan does in fact possess.
# Opinion of 'plot':
# 	 'the', 'and'
#
#
# Sentence:
# 	Sounds like an interesting plot, right?
# Opinion of 'plot':
# 	 'an', 'interesting', ','
#
#
# Sentence:
# 	Feeble direction simply misses several good opportunities to make good use of the jockey's sullen little daughter Sam (Kay Panabaker, her feature debut), who could have been a little surprise (or gem) in this unconvincing plot.
# Opinion of 'plot':
# 	 'this', 'unconvincing'
#
#
# Sentence:
# 	As if the plot matters (it doesn't), the movie is about a woman and her sister who use hubbie's computer to access chat rooms, etc, and witness online killings, and of course, see the killer in a sort of "Eyes of Laura Mars" style.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	2047 however, was the first asian movie that I failed to finish becaase of the sheer BOREDOM of the plot.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	Now if only a bit more attention had been paid to the horror plot, and we might have something here
# Opinion of 'plot':
# 	 'the', 'horror'
#
#
# Sentence:
# 	The only blue here is the shade you will turn by the boredom with the weak plot.
# Opinion of 'plot':
# 	 'the', 'weak'
#
#
# Sentence:
# 	The plot is stupid, and the dialogue is so bad it's over the top.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	The plot was bad and it did not have that many pokemon as I thought.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	...has a pretty thin plot.
# Opinion of 'plot':
# 	 'a', 'thin'
#
#
# Sentence:
# 	The plot of "Hard Target" has been summarized in previous reviews, so I'll limit myself to discussing my favorite part.
# "
# Opinion of 'plot':
# 	 'The', 'of'
#
#
# Sentence:
# 	Scenes like long car drives from the marriage bed to a first infidelity didn't build any dramatic tension or advance a plot or provide any interesting insight into the characters themselves.
# Opinion of 'plot':
# 	 'a'
#
#
# Sentence:
# 	In fact, the trial doesn't even have a connection to the central plot aside from showing that Sam and Archie are friends and partners.
# Opinion of 'plot':
# 	 'the', 'central'
#
#
# Sentence:
# 	The plot and the acting are surprisingly (!) average, while the humor and the dialogues are below average.
# Opinion of 'plot':
# 	 'The', 'and', 'acting'
#
#
# Sentence:
# 	However if you like sex, violence, blood, and debauchery, could care less the fact that they have nothing to do with the absent plot, you could find this film interesting.
# Opinion of 'plot':
# 	 'the', 'absent'
#
#
# Sentence:
# 	The plot was seemed to aimed at kids under 12.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	Come on at least Pokemon has more of a plot.
# Opinion of 'plot':
# 	 'a'
#
#
# Sentence:
# 	Flat lighting, cheap sets and costumes, dull dialog, wooden acting, and a goofy plot; even pervasive silicone enhancement can not save this movie.
# Opinion of 'plot':
# 	 'a', 'goofy'
#
#
# Sentence:
# 	The plot if poorly contrived, the production value is low, the acting for the most part is awful, and it's basically just a way to stitch together a series of music videos which at his age, my son has no interest in.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	The plot is so far beyond lame as to be ridiculous.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	I am just confused about the whole thing really, the plot the characters the ending.....I see other reviews on here about how "creepy" it was, and I just didn't feel that.
# Opinion of 'plot':
# 	 'the', 'characters'
#
#
# Sentence:
# 	Here the emotions are totally disconnected from reality, have nothing to do with what is going on in the screen, and seem only to be there to move the plot, if there is one, along.
# Opinion of 'plot':
# 	 'the', ','
#
#
# Sentence:
# 	Jury Duty simply was just plain awful with it's weak, boring plot and unfunny humor!
# Opinion of 'plot':
# 	 'was', ',', 'boring', 'and', 'humor', '!'
#
#
# Sentence:
# 	It really doesn't take a genius to figure out this plot.
# Opinion of 'plot':
# 	 'this'
#
#
# Sentence:
# 	I mean as soon as the main actress enterred the cabin and heard her husband in the next room I turned to my girlfreind and told her the whole film's plot and sure enough I was right on the money, only I thought it would of ended 20 minutes earlier but oh no, it had to keep going and going...just end allready, I get it!
# Opinion of 'plot':
# 	 'film', 'and'
#
#
# Sentence:
# 	The plot of the movie is interesting and keeps you wondering what is gonna happen next.
# Opinion of 'plot':
# 	 'The', 'of'
#
#
# Sentence:
# 	Thornton--in a role that is nearly wordless except for the voiceover narration tying the plot together--burns a hole in the celluloid with his intense, hangdog gravity.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot does not drag and does not bore
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	I think the acting in the movie was outstanding, the direction was genius, and the plot was amazingly horrific.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	This is all you need to know about the plot because anything else would ruin the film.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot however, is excellent.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	This volume gets right to the heart of the plot, and raises important questions.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	That's enough of the plot--the development, the denouement, and the resolution of which are beautifully realized in both an artistic and an emotional sense.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	There is little danger of giving away the plot; it is not particularly complex.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	Very interesting and unpredictable plot.
# Opinion of 'plot':
# 	 'interesting', '.'
#
#
# Sentence:
# 	Then the plot intervenes.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot feels sluggish at times and there's way too much Xavier Cugat and his orchestra, but Astaire and Hayworth are at their peak, Kern has written some memorable melodies and few could top Mercer at lyric writing, none in Hollywood.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	Basic plot: Ted is a bellhop at an expensive hotel and he's ALONE on New Year's night.
# Opinion of 'plot':
# 	 'Basic', ':', 'is', '.'
#
#
# Sentence:
# 	The bumps in the actions of the characters just did not allow me to focus on the plot throughout.
# Opinion of 'plot':
# 	 'the', 'throughout'
#
#
# Sentence:
# 	Jurassic Park III" simplified the plot, added new dinosaurs, and allowed the characters to develop more than "The Lost World."
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The setting, the plot, the dialogues, the humor, and the music are all wonderful!
# Opinion of 'plot':
# 	 'the', ',', 'are'
#
#
# Sentence:
# 	it was quite funny, but there was less action and less plot compared to other episodes.
# Opinion of 'plot':
# 	 'less', 'compared'
#
#
# Sentence:
# 	The plot of the movie amounts to the inevitable clash between Kowalski and his visiting sister-in-law, Blanche DuBois, a fading Southern belle on the verge of a mental breakdown.
# Opinion of 'plot':
# 	 'The', 'of'
#
#
# Sentence:
# 	Almost the entire plot is onboard and underway.
# Opinion of 'plot':
# 	 'Almost', 'the', 'entire'
#
#
# Sentence:
# 	I don't want to give the plot of the movie away, so I won't go into great detail.
# Opinion of 'plot':
# 	 'the', 'of'
#
#
# Sentence:
# 	Since there isn't really a plot to speak of, the movie is told as a series of episodes, Goodfellas-style, with several extended pieces--the pool party at Jack's House where Eddie/Dirk gets introduced to the whole crew; the New Year's Eve party celebrating the start of the '80's; the fake drug deal gone bad at a Rahad's house--serving to turn the narrative in new directions.
# Opinion of 'plot':
# 	 'a', 'speak'
#
#
# Sentence:
# 	From there it just gets progressively darker and tenser, with the lighting, acting, and direction all perfectly serving to ratchet up the feeling of desperation and horror as Todd kicks his ill-conceived robbery plot into motion and things spin way out of control.
# Opinion of 'plot':
# 	 'his', 'conceived', 'robbery', 'into', 'and'
#
#
# Sentence:
# 	The plot of this 100 percent attention-keeper thickens as its characters sicken.
# Opinion of 'plot':
# 	 'The', 'of', 'as', '.'
#
#
# Sentence:
# 	The plot was well put together and solid.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	i rate this episode a 5/10, simply because it lacked action and plot, plus the man telling the story is looking back thirty years to when the episode occured.
# Opinion of 'plot':
# 	 ','
#
#
# Sentence:
# 	As the plot progresses, Nishi reveals his reasons for saving Wada and exacting a very personal revenge on Iwabuchi and his cohorts; the story's pace becomes more frantic and exciting.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	Don't watch this film if you need action or a plot.
# Opinion of 'plot':
# 	 'a'
#
#
# Sentence:
# 	While it's hard to pick my favorite first season episode, the complex plot of "A Priest, A Doctor & Medium Walk into an Execution Chamber" is a jewel, with the police chasing a ghost who apparently has just committed murder.
# Opinion of 'plot':
# 	 'the', 'complex', 'of'
#
#
# Sentence:
# 	The plot was well worn, but it didn't feel staid or plodding.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	The plot is perfect and the script is well written.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	Ed Begley as the CIA boss adds weight and color to that aspect of the plot, and Richard Libertini as the South American dictator (I've never seen him play a sane character) adds another kind of raucous fun.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot is sweet.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	The third film, "The Last Crusade", is possibly the most balanced in terms of plot and charactor, and has the wonderful Sean Connery to steal every scene he's in.
# Opinion of 'plot':
# 	 'and', 'charactor'
#
#
# Sentence:
# 	WHAT WORKS: The title sequence is great, perhaps one of the best in all of cinema (another Amazon reviewer noted this, so I'm not alone); the soundtrack is phenomenal ('nuff said); the plot is intriguing; the humanimal make-up is fine ('Hyena' looks especially horrific); the film possesses an undeniable creative pizzazz (i.e. it's moody, atmospheric and insane); and Marlon Brando's 35 minute stint in the film is as captivating as always (you can probably tell I'm a huge Brando fan -- in particular, "One-Eyed Jacks," "Mutiny on the Bounty" (1962), "The Young Lions," "Superman" and "Apocalypse Now" [not "Redux"]).
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The quality of the graphics are terrific, the plot is a little strange, but basically its aliens who invade and ride 4 virtual roller coasters at a futuristic theme park.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	I borrowed this movie from a friend and looking at it, it appears to be one of those movies with no plot and just a lot of nudity.
# Opinion of 'plot':
# 	 'no', 'and', 'lot'
#
#
# Sentence:
# 	Well, this movie does have a plot and it's quite complicated.
# Opinion of 'plot':
# 	 'a'
#
#
# Sentence:
# 	Another player in the plot is Ray Duquette (Kevin Bacon), the detective investigating the rapes who is skeptical of both stories.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The setting, the plot (Jeff's strong sense of love, devotion, and determination are admirable and commendable, and an example for all to follow!), the dialogues and the music are all wonderful!
# Opinion of 'plot':
# 	 'the', '(', 'sense', 'devotion'
#
#
# Sentence:
# 	This set comes with twelve discs each packaged in a cardboard slipcase with brief descriptions of the plot, every disc is double sided and contains two films on each side.
# Opinion of 'plot':
# 	 'the', ','
#
#
# Sentence:
# 	(The Star of David representing Judaism and a cross representing Christianity)
#
# I haven't seen the movie in years but I don't remember a conflict in religious beliefs being part of the plot.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	This is a story-driven film, with a plot that progresses fairly slowly.
# Opinion of 'plot':
# 	 'a', 'progresses'
#
#
# Sentence:
# 	The supporting roles are superbly done, the tension in the plot is sustained well until the end, and when this shows up on cable TV I almost always watch it again for a half-hour or so.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	I can sit here and give away the plot but in order for you, the viewer to truly enjoy it, I'm not! When I saw TIMELINE for the first time it was in order to see another wonderful DONNER PRODUCTION and Billy Connolly, a Scot to whom my heart had been lost.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot is really about their burgeoning relationship, while his mother constantly attempts to make the death-obsessed Harold more socially acceptable.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	But mostly this film is weak in that it bored me because there was no plot.
# Opinion of 'plot':
# 	 'no'
#
#
# Sentence:
# 	This is a great kid's movie with a lot of characters and a great story plot.
# Opinion of 'plot':
# 	 'a', 'great', 'story'
#
#
# Sentence:
# 	That is all I want to say about the plot but it does get interesting.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	In the Japanese one it is touching because the whole time the ghost was reaching out for help.  anyway i recommend this to anyone who loves  Asian horror and likes a good plot and movie!!
# Opinion of 'plot':
# 	 'a', 'good', 'and', 'movie'
#
#
# Sentence:
# 	The plot is not very intriguing, and you know that nothing like this can happen in the real life, so it lacks this sense of reality.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	I'm not a movie buff, but Deep Cover has all the elements you would expect of a classic : great acting, memorable lines, interesting ( and logical ) plot and a decent ending.
# Opinion of 'plot':
# 	 'interesting', 'and', 'ending'
#
#
# Sentence:
# 	This is a wonderful film, with a silly but extremley funny plot, and some wonderful dialogue, particularly between Horton and Brady, who somehow manage to end up married to each other, much to their surprise.
# Opinion of 'plot':
# 	 'a', 'silly', 'funny', ',', 'and', 'dialogue'
#
#
# Sentence:
# 	The plot evolves as many other Coen movies (Raising Arizona comes to mind) as we are introduced to more-and-more colorful characters and the plot gets more-and-more outrageous, yet somehow still seems real.
# Opinion of 'plot':
# 	 'The', 'more', 'the'
#
#
# Sentence:
# 	The plot:
# The movie kicks off with a man narrating.
# Opinion of 'plot':
# 	 'The', ':', 'kicks', '.'
#
#
# Sentence:
# 	The plot thickens when the police become involved, thanks to Carol.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	Everyone knows the basic plot by now: Spock kidnaps his crippled former Captain, and hijacks the Enterprise, and sets course for the one forbidden planet in all The Federation.
# Opinion of 'plot':
# 	 'the', 'basic', 'by', ':', 'kidnaps'
#
#
# Sentence:
# 	None of these are very important to the plot of EITHER the pilot or the envelope.
# Opinion of 'plot':
# 	 'the', 'of', 'pilot'
#
#
# Sentence:
# 	Everybody knows the plot of this movie.
# Opinion of 'plot':
# 	 'the', 'of'
#
#
# Sentence:
# 	I really liked that the plot explored more themes than just romantic love.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	Yes, the plot is odd.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	But that plot seems to always work.
# Opinion of 'plot':
# 	 'that'
#
#
# Sentence:
# 	It doesn't follow a storyline that's predictable, even though the plot is not unknown.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	It uses one of the worst superhero cliches as the main plot, that of the hero calling it quits.
# Opinion of 'plot':
# 	 'the', 'main'
#
#
# Sentence:
# 	Bottom Line: You will be entranced while following the plot and pleasantly shocked the surprise ending.
# Opinion of 'plot':
# 	 'the', 'and'
#
#
# Sentence:
# 	Great acting and development in the multi-linear plot movie.
# Opinion of 'plot':
# 	 'linear'
#
#
# Sentence:
# 	On hearing this, Burns hatches his plot.
# Opinion of 'plot':
# 	 'his'
#
#
# Sentence:
# 	There's a shadowy plot involving $10,000 bills, a guerilla movement and guns, but the movie focuses more on Quinn's conflicts because his childhood friend is suspected of a grisly murder, and Quinn's own discomfort from having "made good" but ending up caught between two worlds, white and black.
# Opinion of 'plot':
# 	 'a', 'shadowy', 'involving', 'focuses'
#
#
# Sentence:
# 	No matter that we couldn't quite figure out if the plot hung together.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot focuses on Wil, short for Wilhelmina, an obviously talented Manhattan-based surgical resident who has kept herself closeted from her traditional Chinese family living across the East River in Flushing.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	Was it cancelled because the plot was flimsy or dumb?
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot, the setting, the dialogues, the special effects, and the music are all wonderful!
# Opinion of 'plot':
# 	 'The', ',', 'setting', 'are'
#
#
# Sentence:
# 	The plot is interesting, it keeps you guessing, and the suspense keeps you on the edge of your seat.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	During their journey, they see and do many wonderous things in wonderland (I wont say anymore, I dont want to spoil too much of the plot).
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	His character, who seemed quite smarmy to me, did figure into the plot, but it just felt like his lengthy performances were included to help pad out a decent running time.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	" The drama part is the Judah plot.
# Opinion of 'plot':
# 	 'the', 'Judah'
#
#
# Sentence:
# 	The comedy is the Cliff plot.
# Opinion of 'plot':
# 	 'the', 'Cliff'
#
#
# Sentence:
# 	I knew that I wanted this movie, but I had forgotten much of the plot.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot takes many twists and turns as Cora and Frank try to outmaneuver the law, Nick, and also a pair of unscrupulous lawyers who are intent to see the sultry couple double-cross and sell out on each other.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	Directed by Tamra Davis with a keen eye on characterization and humor, this movie is one of those you smile most of the time, and have a good time with its surreal and zany plot.
# Opinion of 'plot':
# 	 'its', 'surreal'
#
#
# Sentence:
# 	So is she, but, I can't tell you what happens without giving away this poignant part of the plot.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot wasn't horrible, it was actually pretty good for a fright flick.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	The plot, the setting, the acting, and the dialogues are all very good.
# Opinion of 'plot':
# 	 'The', ',', 'setting', 'are'
#
#
# Sentence:
# 	Now, not only is the plot and the dialogue and everything true-to-life but this film is also absolutely hilarious.
# Opinion of 'plot':
# 	 'the', 'and', 'dialogue'
#
#
# Sentence:
# 	This series has a plot, good writing and good production values.
# Opinion of 'plot':
# 	 'a', ',', 'values'
#
#
# Sentence:
# 	The plot is complex.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	Even though the film is based on a fictional plot, it still has an authentic feel and is rated an all time classic
# Opinion of 'plot':
# 	 'a', 'fictional'
#
#
# Sentence:
# 	The plot concerns a race between good guy Lewis Stone and Fu Manchu to find the tomb of Ghengis Khan.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	I won't give any more of the plot away, but just remember the phrase "synthetic flash."
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot concerns the death of Sir Karell Borotyn, who appears to have been killed by vampire Count Mora.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	The plot is good, and Deoxys' 'destructive' intentions are less cruel than one would think.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	The plot is stupid, the characters are dull and insipid, and the whole movie leaves you asking, as the credits run, "So What?" Don't waste your money!
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	That said, I want to say a few words about the plot.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	I don't wish to give away the plot about what happened to her, however, I will write that Barney contacts Jeff and tells him that he admires his persistence in trying to locate Diane after so many years.
# Opinion of 'plot':
# 	 'the', 'about'
#
#
# Sentence:
# 	The plot and dialogue is incredible because it explores all the shades of grey in the characters.
# Opinion of 'plot':
# 	 'and', 'dialogue'
#
#
# Sentence:
# 	Pollack takes all that intricately woven little Grisham-plot and barfs big ugly chunks of it up on the screen.
# Opinion of 'plot':
# 	 'Grisham', '-', 'and', 'barfs'
#
#
# Sentence:
# 	the plot was pretty original.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	Furthermore, they fail to make enough sequential sense of the film's plot to really mean much to the film as a greater whole.
# Opinion of 'plot':
# 	 'film'
#
#
# Sentence:
# 	The plot's conclusion quails in the face of the "so what?" question.
# Opinion of 'plot':
# 	 'The', ''s'
#
#
# Sentence:
# 	Standard film review requires a plot summery, but in 'The Salton Sea' it doesn't work.
# Opinion of 'plot':
# 	 'a'
#
#
# Sentence:
# 	This film may not be perfect, and there are some boring scenes as they try to hard to explain the state Nick is in, but the overall plot of this film is one I've never seen done before.
# Opinion of 'plot':
# 	 'the', 'overall', 'of'
#
#
# Sentence:
# 	I enjoyed the acting and the premise behind the plot
# Opinion of 'plot':
# 	 'the', '
# '
#
#
# Sentence:
# 	One Hour Photo.
#
# *** 3/4
#
# Many people have covered the film's plot.
# Opinion of 'plot':
# 	 'film'
#
#
# Sentence:
# 	Giving the plot away would be moot, since it is a portrayal of everyday life for people of this particular scene.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The later revised version considerably weakened both characters and plot, and the "concert" version is even more woefully incomplete than the original cast album, but thank GOD they saw fit to include, "Too Many Mornings".
# Opinion of 'plot':
# 	 ',', 'and', 'the'
#
#
# Sentence:
# 	The plot is pretty unrealistic
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	As I said the plot's formulaic as you have the standard setup of the main character creating a wacky situation, one that eventually gets out of hand, ultimately crashing down around his ears, resulting in a last ditch effort to save the day.
# Opinion of 'plot':
# 	 'the', ''s'
#
#
# Sentence:
# 	It combines a bunch of the best French actrices, and an enjoyable plot.
# Opinion of 'plot':
# 	 'an', 'enjoyable'
#
#
# Sentence:
# 	the plot was dry, like the other 2 of the series, but how exciting of a plot can you have with the amount of action and skilled driving packed into the movie.
# Opinion of 'plot':
# 	 'the', 'a'
#
#
# Sentence:
# 	Sure the plot of weak and the relationships are unbelievable, I mean who can honestly say that they feel a kingpin to the Japanese/Chinese/Oriental (whatever it was) Mafia is going to agree to have his nephew and some stranger race to squash their beef?
# Opinion of 'plot':
# 	 'Sure', 'the', 'of', 'are'
#
#
# Sentence:
# 	This film has some good actors in it but the plot is pretty shaky and hard to follow at times.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	It could have been made better--less comedy and more plot and of course --action and suspense!!!!
# Opinion of 'plot':
# 	 'more', 'and', '--action'
#
#
# Sentence:
# 	The plot was very st8 foward and basic with a few little tid bits to living it up.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	It is the portrait of a brilliant, but profoundly troubled old man who weeps about selecting a plot of ground in Arlington in which to bury JFK, but is steel-eyed as he recounts bombing sorties that destroy hundreds of thousands.
# Opinion of 'plot':
# 	 'a', 'of'
#
#
# Sentence:
# 	Without Kate Bosworth this movie would have not been so great, she makes it what it is because she is uniquely cute
#
# the plot is that she works in a grocery store where the dorky, half-mast eyed manager likes her but she wins a date with tad hamilton who turns out to be not such a punk but he can't come up with good lines to say to her, so he steals the dorky guys lines, but when she fines out on the plane, she makes him take her back to the dorky guy, who is getting advice from the troglodyte bartender chick who thinks he's really hot.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	I mainly took off a point for the artwork and the plot being drawn out at points.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot is very good.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	That they did but, unfortunately, the producers forget to give them a credible plot and interesting things to say.
# Opinion of 'plot':
# 	 'a', 'credible', 'and', 'things'
#
#
# Sentence:
# 	Aside from the plot is powerful acting by powerful actors.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	People who review Spielberg usually want to pigeonhole him into a type: the ET-warm-and-fuzzy-alien children's storyteller versus the special-effects-heavy-but-rather-empty-plot dreamer.
# Opinion of 'plot':
# 	 'empty', '-'
#
#
# Sentence:
# 	The plot is slow to develop, character development lacking and animation primitive at best.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	Both films have the same borring plot.
# Opinion of 'plot':
# 	 'the', 'same', 'borring'
#
#
# Sentence:
# 	I loved the new version with the added scenes (even though they aren't significant to the plot it's nice to be able to watch them).
# Opinion of 'plot':
# 	 'the', ''s'
#
#
# Sentence:
# 	The actors are simply magnificent, And the cinematographic aproach to the plot is superb, original and fresh.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	"A Beautiful Mind" put a lot of effort into putting real math into the plot, and I like that.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot is about a writer who wants to create a book of horror stories.
# Opinion of 'plot':
# 	 'The'
#
#
# Sentence:
# 	Unfortunately, the show is not as slick as the plot sounds.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	Maybe the next few volumes will be more creative and give more details on the main plot, but I personally don't care to spend anymore of my money on such a risk.
# Opinion of 'plot':
# 	 'the', 'main'
#
#
# Sentence:
# 	This is not good, simply because the producers and the writers probably went crazy themselves trying to emulate the real time-traveling pros, while winding up with some abrubt, nonsense end of the movie, with absolutely no sci-fi logic at all: they simply had to eventually stop shooting, so they just thought any happy ending would have done the trick, no matter the time differences and the numberless loose ends still untied in the plot.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	You really care about all these characters, even though you might not understand every single detail of the plot.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	This was a very good movie, if you can set aside the fact that it has no plot whatsoever.
# Opinion of 'plot':
# 	 'no', 'whatsoever'
#
#
# Sentence:
# 	The bad: Not a very interesting or profound plot.
# Opinion of 'plot':
# 	 'Not', 'a', 'interesting'
#
#
# Sentence:
# 	There's not much of a plot and the movie is more of a snapshot of the lives of these characters upon their first interactions.
# Opinion of 'plot':
# 	 'a', 'and'
#
#
# Sentence:
# 	The plot of the story is really interesting.
# Opinion of 'plot':
# 	 'The', 'of'
#
#
# Sentence:
# 	I think the acting in the movie was outstanding, the direction was genius, and the plot was amazingly horrific.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The movie gallops in speed as we are absorbed into the great plot and brilliant acting of all the cast involved.
# Opinion of 'plot':
# 	 'the', 'great', 'and', 'brilliant'
#
#
# Sentence:
# 	The best thing about this movie was the depth of the plot and the actors playing their characters so well.
# Opinion of 'plot':
# 	 'the', 'and', 'actors'
#
#
# Sentence:
# 	The plot's excellent, but the show stopping tunes are real blow-outs!
# Opinion of 'plot':
# 	 'The', ''s'
#
#
# Sentence:
# 	And Michelle always looks adorable.  Loved the plot, perfect family, perfect house, perfect dog, perfect friends, perfect husband, a scientist with a big salary no less, perfect size 2 wife, and something hidden, dirty and horrifying to screw it all up.
# Opinion of 'plot':
# 	 'the', ',', 'family'
#
#
# Sentence:
# 	While the plot is nearly identical, Alexander Payne (director) treats his characters much harsher than Perrotta.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	Most of us don't know much about legal issues but are still interested in thrillers, and this movie shows a rather believable and very fun plot.
# Opinion of 'plot':
# 	 'a', 'believable'
#
#
# Sentence:
# 	I think the acting in the movie was outstanding, the direction was genius, and the plot was amazingly horrific.
# Opinion of 'plot':
# 	 'the'
#
#
# Sentence:
# 	The plot has some problems, but with solid acting by Both Jones and Ashley, this is a decent way to pass a couple hours.
# Opinion of 'plot':
# 	 'The'
#
#
# ...
#
#
# Sentence:
# 	The characters are likeable and complex and the animation is great.
# Opinion of 'characters':
# 	 'The'
#
#
# Sentence:
# 	The script is so well written that it must have been a dream to explore who these characters were and the world in which they lived.
# Opinion of 'characters':
# 	 'these'
#
#
# Sentence:
# 	The characters still retain their gritty determination as well as their rough Aussie and Irish immigrant dialects.**
# Opinion of 'characters':
# 	 'The'
#
#
# Sentence:
# 	One also sees the characters "coming into their own" during this season.
# Opinion of 'characters':
# 	 'the'
#
#
# Sentence:
# 	Jason, Melissa and Brendan all begin to show more consistent personality traits that really allow one to bond with their characters.
# Opinion of 'characters':
# 	 'their'
#
#
# Sentence:
# 	And 90% of the characters looked exactly like their comic strip counterparts.
# Opinion of 'characters':
# 	 'the'
#
#
# Sentence:
# 	Part of Dickens' genius was the ability to enable the reader to FEEL
# the time and place of the storyline unfolding, as well as the visualize
# the gamut of intriguing characters.
# Opinion of 'characters':
# 	 'intriguing'
#
#
# Sentence:
# 	This has an interesting story with great characters and great direction.
# Opinion of 'characters':
# 	 'great', 'and', 'direction'
#
#
# Sentence:
# 	Leslie Howard (who I always found a bit 'weak' as an actor - or maybe it was the characters he played!) fits this role like a glove as the famous husband who falls hopelessly in love with his daughters piano teacher (played by Ingrid).
# Opinion of 'characters':
# 	 'the', 'played'
#
#
# Sentence:
# 	The characters come alive, and I love to "learn my history" in this manner.
# Opinion of 'characters':
# 	 'The'
#
#
# Sentence:
# 	Just some of the popular characters included the underachieving & sneaky, Joey Jeramiah (Pat Mastroianni), the sexually assertive school President, Stephanie (Nicole Stoffman) her nerdy little brother, Arthur (Duncan Waugh), the caring and concerned, Caitlin (Stacie Mistysin), tough guy, Rick (Craig Driscoll) rock guitarist, Snake (Stephan Brogan) and his friend and fellow bass player, Wheels (Neil Hope).
# Opinion of 'characters':
# 	 'the', 'popular'
#
#
# Sentence:
# 	In the first season we are just being introduced to the many characters, episode by episode.
# Opinion of 'characters':
# 	 'the', 'many', ',', 'episode'
#
#
# Sentence:
# 	Well the issues it dealt with seemed real and not sensationalized mixed in with reoccurring characters who all gave a generally believable performances.
# Opinion of 'characters':
# 	 'reoccurring', 'gave'
#
#
# Sentence:
# 	It's great to be reacquainted with all the characters and story-lines again.
# Opinion of 'characters':
# 	 'all', 'the', 'and', 'lines'
#
#
# Sentence:
# 	It's a shame they don't show this on television anymore, so few shows today exude a sense of genuine concern for its characters as Degrassi did
# Opinion of 'characters':
# 	 'its', 'as'
#
#
# Sentence:
# 	From Dostoyevsky's despised "Poor Folk", to his Possessed intellectuals(Raskolnikov and reprobate "double" Svidrigailov,essayed by Anthony Bate of BBC's "Tinker,Tailor, Soldier,Spy"); to heroic women(Sonia,played by Yolande Palfrey; Dounia, played by Pruella Ransome;and Raskolnikov's mother,played by Yvonne Coulette)comprising Dostoyevsky's incarnation of THE HOLY SPIRIT; to wily,yet ultimately merciful Chief Magistrate, PORFIRY PETROVICH (said to be precursor of America's detective Columbo):the battle-array of characters that proclaim Dostoyevsky as,perhaps,world's greatest novelist is brought to life in all its Russian glory,courage,love and shame.
# Opinion of 'characters':
# 	 'proclaim'
#
#
# Sentence:
# 	In fact Bruce steals the show where she not only has to translate a fight with John and Flor but she nails the shifting emotional states of both characters.
# Opinion of 'characters':
# 	 'both'
#
#
# Sentence:
# 	If we zoom in on his past films, we see the heavy detail given to the characters.
# Opinion of 'characters':
# 	 'the'
#
#
# Sentence:
# 	The film's success relies heavily on how the characters play off each other, especially to Vega, whose entrance into the lives of everyone around her affect them and her.
# Opinion of 'characters':
# 	 'the'
#
#
# Sentence:
# 	It is about the communication or lack thereof between the characters.
# Opinion of 'characters':
# 	 'the'
#
#
# Sentence:
# 	Any way Claudia was a prowerful character and I think Kristin at times out shined even Brad and Tom's characters.
# Opinion of 'characters':
# 	 'Tom'
#
#
# Sentence:
# 	I've never considered the matter before, but I think actors enjoy playing bad guys even more than good guys, since that's one thing you can't do in real life without negative consequences.
#
# I've spent a lot of time on Lex and his father so I don't want to overlook the other characters, but as I just wanted to write a brief review, I'll just say they're all really great in their roles too, especially Tom Welling and Kristen Kreuk.
# Opinion of 'characters':
# 	 'the', 'other'
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
# Sentence:
# 	First, the dialogue and situations are so insipid they often inspire unintentional hilarity.
# Opinion of 'dialogue':
# 	 'the', 'and', 'situations'
#
#
# Sentence:
# 	Some portions of the TV dialogue are lost in thick Yorkshire accents and unintelligible dialect, interesting only to language scholars.
# Opinion of 'dialogue':
# 	 'the', 'TV'
#
#
# Sentence:
# 	Without contrived manipulations, you are drawn into the depths and heights of their emotions through the use of stunning visuals, dramatic portrayals, pithy dialogue, moments of quiet contemplation, and a serene musical soundtrack that is worth owning on its own merits.
# Opinion of 'dialogue':
# 	 'pithy', ',', 'moments'
#
#
# Sentence:
# 	It offers a winning combination of drama and comedy, a certain realism that is only acquired through good dialogue and silence.
# Opinion of 'dialogue':
# 	 'good', 'and', 'silence'
#
#
# Sentence:
# 	It's not above the occasional cheap joke but counters it with some of the smartest and most off-the-wall pop cultural riffs in its dialogue that even those of us who identify them immediately still must blink twice that we actually heard someone in a mainstream comedy speak them. Comedies of this caliber don't come along too often.
# Opinion of 'dialogue':
# 	 'its'
#
#
# Sentence:
# 	It has his trademark realistic dialogue and without any flashy effects he focuses on the characters.
# Opinion of 'dialogue':
# 	 'his', 'trademark', 'realistic', 'and'
#
#
# Sentence:
# 	The dialogue is warm and witty and the actors are wonderful.
# Opinion of 'dialogue':
# 	 'The'
#
#
# Sentence:
# 	I loved this movie. Loved the dialogue, the humour, and the performances.
# Opinion of 'dialogue':
# 	 'the', ',', 'humour'
#
#
# Sentence:
# 	Allen's dialogue (which is always good) is particularly good in the conversations between Isaac and Mary; The final scene between Isaac and Tracy is also very meaningful and very good.
# Opinion of 'dialogue':
# 	 'Allen', '(', 'is'
#
#
# Sentence:
# 	Like the other movies there is some great dialogue in this movie and I highly recommend the movie to fans of Chris Farley, Chris Rock and SNL.
# Opinion of 'dialogue':
# 	 'some', 'great', 'in', 'and'
#
#
# Sentence:
# 	Pollack was apprehensive about placing himself in the film, but his presence personalizes the exercise and introduces a dialogue between these 2 men who both "try to find personal expressiveness within disciplines that make stringent commercial demands".
# Opinion of 'dialogue':
# 	 'a', 'between', '"'
#
#
# Sentence:
# 	I was very disappointed with the video quality and the dialogue.
# Opinion of 'dialogue':
# 	 'the'
#
#
# Sentence:
# 	Keaton, Chaplin, & Lillian Gish, I'd offer, were masters of this; in effect, conveying 5 pages of dialogue for each silent scene they acted through.
# Opinion of 'dialogue':
# 	 'for'
#
#
# Sentence:
# 	Yes, the movie has flaws: the dialogue can be a little goofy at times, the acting somewhat- shall we say - idiosyncratic, the special effects don't always work, and the internal logic is not always apparent (the Grail is Arthur?
# Opinion of 'dialogue':
# 	 'the'
#
#
# Sentence:
# 	"It is a time for men and their ways," and other Gandlaf like speech is peppered throughout his dialogue.
# Opinion of 'dialogue':
# 	 'his'
#
#
# Sentence:
# 	With cringingly awful acting, laughable special effects (the ridiculous head in a bucket is a real guffaw moment), appalling dubbed dialogue, cheesy music, inconsistent and confusing plot and no tension or atmosphere, The Grim Reaper is a total disaster.
# Opinion of 'dialogue':
# 	 ','
#
#
# Sentence:
# 	These pictures often boast well-developed characters, evolving situations that reveal complex motives, thereby building drama, and carefully hewn dialogue.
# Opinion of 'dialogue':
# 	 'hewn'
#
#
# Sentence:
# 	The early part of this film is filled both with snappy, intelligent dialogue but also with a sophomoric physical comedy which can honestly be considered to be at or below a pie-in-the-face level of sophistication.
# Opinion of 'dialogue':
# 	 'snappy', 'but'
#
#
# Sentence:
# 	But however dated these physical antics seem by today's standards, the witty banter of the dialogue holds up quite well.
# Opinion of 'dialogue':
# 	 'the'
#
#
# Sentence:
# 	Between incredibly bad dialogue about things like the "plutonium-ruby crystal beam gun," silly incidental music, and a Venusian made of latex, twigs, and tissue paper, this one cannot be beat.
# Opinion of 'dialogue':
# 	 'bad', 'about'
#
#
# Sentence:
# 	Baumbach's screenplay boasts lots of memorable dialogue, lots of cleverness you might find yourself "borrowing."
# Opinion of 'dialogue':
# 	 'memorable', ',', 'lots'
#
#
# Sentence:
# 	Now, not only is the plot and the dialogue and everything true-to-life but this film is also absolutely hilarious.
# Opinion of 'dialogue':
# 	 'the', 'and', 'everything'
#
#
# Sentence:
# 	The dialogue is quick-witted, some the scenes have become classics (Allen sneezing on the cocaine).
# Opinion of 'dialogue':
# 	 'The'
#
#
# Sentence:
# 	The great sweet beauty of this film, however, is the marriage of such engaging dialogue, such earnest deadpan deliveries shot in such eerie clarity--one reminiscent of the interiors in Dutch genre painting: clean, homely, homiletic.
# Opinion of 'dialogue':
# 	 'such', 'engaging'
#
#
# Sentence:
# 	It manages to turn a suite of classically static images-bronzed, burnished, melancholy-upon a fast-driving dialogue endowed with the modest but enhancing artificiality of a painting, a novel or--better yet--an infinitely refined film
# Opinion of 'dialogue':
# 	 'a', 'driving', 'endowed'
#
#
# Sentence:
# 	Many will be moved by how natural the dialogue sounds (he recorded most of it on the streets), a lot of it obviously inspired by his own life.
# Opinion of 'dialogue':
# 	 'the'
#
#
# Sentence:
# 	Their dialogue is as fast as their wits: "I wish you hadn't done that, Hildy."
# Opinion of 'dialogue':
# 	 'Their'
#
#
# Sentence:
# 	Indeed, the dialogue is so beautifully eloquent, we feel like we are often given the modern equivalent of Shakespeare.
# Opinion of 'dialogue':
# 	 'the'
#
#
# Sentence:
# 	Selection of
# locations, environments and characters is simply wonderful -- sure to
# keep the viewer engrossed, even though the dialogue is uncompromisingly
# British.
# Opinion of 'dialogue':
# 	 'the'
#
#
# Sentence:
# 	Recent adaptations seem afraid to include original dialogue at any length- this gave us so much that was gripping and character-revealing.
# Opinion of 'dialogue':
# 	 'original', 'at'
#
#
# Sentence:
# 	Now I should get this out of the way: Sandler doesn't feel miscast, in fact he's quite good, despite some Sandler-esque bits (his dialogue during a rather strange love scene is very reminiscent of his other stuff) but I think his presence suggests this is going to be a low-brow humor geared to frat boys.
# Opinion of 'dialogue':
# 	 'his', 'during'
#
#
# Sentence:
# 	Very witty dialogue and scenes; flawless acting by lead and supporting actors.
# Opinion of 'dialogue':
# 	 'witty', 'and', 'scenes', ';', 'flawless', '.'
#
#
# Sentence:
# 	My wife says all of his movies are the same, and it breaks my heart everytime she says it...because in that blanket analysis, the analyst misses the incredible stories and crafty dialogue that takes place in the many Woody Allen movies that pretty much take place within the same template.
# Opinion of 'dialogue':
# 	 'crafty', 'takes'
#
#
# Sentence:
# 	Their dialogue is as fast as their wits: "I wish you hadn't done that, Hildy."
# Opinion of 'dialogue':
# 	 'Their'
#
#
# Sentence:
# 	Not to mention the costumes, dialogue, vehicles and more importantly the characters in the film itself.
# Opinion of 'dialogue':
# 	 ',', 'vehicles'
#
#
# Sentence:
# 	The effects are so terrible that its hard not to burst out laughing when one of the main characters have a dialogue and a fight with a beachball (!).
# Opinion of 'dialogue':
# 	 'a', 'and', 'fight'
#
#
# Sentence:
# 	Most of the dialogue was spoken at Tommy Gun blast speed, with every word clearly enunciated - a feat in itself!  All the men are mostly in suits or tuxes, and the women wear the most beautiful outfits, created by the top designers in the world at the time.
# Opinion of 'dialogue':
# 	 'the'
#
#
# Sentence:
# 	This is a must-have if you like a good story line, clever dialogue and honest laughs.
# Opinion of 'dialogue':
# 	 'a', 'have', 'like', 'clever', 'and', 'laughs'
#
#
# Sentence:
# 	Great for the purest in the crowd but killer for those of us who like badly dubbed English dialogue.
# Opinion of 'dialogue':
# 	 'English'
#
#
# Sentence:
# 	The absence of this live theatre audience, especially one schooled in the particular genres popular to theatregoers of Shaw's time, may prove somewhat alienating for some, especially as the dialogue and plot recall a more literary era with social conventions that are no longer conventional.
# Opinion of 'dialogue':
# 	 'the', 'and', 'plot'
#
#
# Sentence:
# 	The dialogue of Murder, My Sweet has to be heard to be believed (Marlowe: "My fingers looked like a bunch of bananas"), but Dick Powell pulls it off with aplomb.
# Opinion of 'dialogue':
# 	 'The', 'of'
#
#
# Sentence:
# 	The weaknesses were immediately apparent--awkward dialogue, lack of visual style--but I hoped the movie would overcome its faults.
# Opinion of 'dialogue':
# 	 'awkward', ',', 'lack'
#
#
# Sentence:
# 	This may help some of you slower people (don't be ashamed) to understand the film, although much of its important intricate dialogue and overall appeal will be lost in this version.
# Opinion of 'dialogue':
# 	 'its', 'important', 'intricate', 'and', 'appeal'
#
#
# Sentence:
# 	The effects are so terrible that its hard not to burst out laughing when one of the main characters have a dialogue and a fight with a beachball (!).
# Opinion of 'dialogue':
# 	 'a', 'and', 'fight'
#
#
# Sentence:
# 	There are problems with the film, the most annoying one being that the dialogue is practically inaudible due to the miking and, more so, due to the musical score which covers all the lines to the point of making the movie seem like a silent movie with music from the pit!  Such a shame, because it SEEMS like this is a good script with a lot to say.
# Opinion of 'dialogue':
# 	 'the'
#
#
# Sentence:
# 	If only the ugly and senseless music hadn't submerged the dialogue (oddly enough the score was written by Michael Bacon!), this would be an Oscar contender.
# Opinion of 'dialogue':
# 	 'the', 'written'
#
#
# Sentence:
# 	That part of the film is done poorly here with little that is fresh in the way of dialogue or plot.
# Opinion of 'dialogue':
# 	 'or', 'plot'
#
#
# Sentence:
# 	All of the characters have good chemistry together and the dialogue tends to be very witty at times (esp.
# Opinion of 'dialogue':
# 	 'the'
#
#
# Sentence:
# 	The mood, the sensuous dialogue; This is just noir at it's best.
# Opinion of 'dialogue':
# 	 'the', 'sensuous'
#
#
# Sentence:
# 	This tart, well-scripted comedy is a little light on the dancing, but features some of the best, briskest dialogue that came Astaire's way, and a fine supporting cast, including the famous Hollywood &quot;double-talker,&quot; Cliff Nazarro, going through his routine in numerous scenes.
# Opinion of 'dialogue':
# 	 'briskest', 'came', 'and', 'fine'

# %%
# %load solutions/opinion_extractor_initial

# %% [markdown]
# ### Exercise
# Look at the output that your opinion extractor is producing.
#
# As you can see, it isn't very good. In the sections below, you will be looking at a variety of ways in which you can refine the `opinion_extractor` function to improve its performance.
#
# The work you will do in the remainder of this notebook forms part of the first assessed coursework for this module. This will involve developing and assessing the effectiveness of several extensions to the opinion extractor.
# - For full details of what is required for the coursework see the coursework specification document which can be downloaded from the module website.
#
# Have a look at the section **Tips for de-bugging and exploration** (see below).
#
# As you are investigating how well your `opinion_extractor` is working, you will want to view your opinion extractor's output for a substantial number of sentences. You might prefer to print your output to a file.
#
# The code in the next cell illustrates how this below.
# - Note that you may wish to replace `"savefile.txt"` with a different path.

# %%
save_file_path = r"savefile.txt" # Set this to the location of the file you wish to create/overwrite with the saved output.

# This is a "with statement", it invokes a context manager, which handles the opening and closing of resources (like files)
with open(save_file_path, "w") as save_file:  # The 'w' says that we want to write to the file            
    for parsed_review in parsed_reviews:
        for sentence in parsed_review.sents:
            for aspect_token in aspect_words:
                opinions = opinion_extractor(aspect_token,sentence)
                if opinions:
                    save_file.write("--- Sentence ---\n{0}\nOpinions on {1}\n{2}\n".
                                    format(sentence,aspect_token,opinions))
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-27-467b264fee6e> in <module>()
#       9                 if opinions:
#      10                     save_file.write("--- Sentence ---\n{0}\nOpinions on {1}\n{2}\n".
# ---> 11                                     format(sentence,aspect_token,opinions))
#
# C:\ProgramData\Anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\ufffd' in position 69: character maps to <undefined>

# %% [markdown]
# ## Required extensions
# There are 5 required extensions:
# 1. Adjectivel modification
# 2. Adjectives linked by copulae
# 3. Adverbial modifiers
# 4. Negation
# 5. Conjunction
#
# In addition there are a number of optional extensions (see below).
#
# ### Example test set
# In addition to testing out your opinion extractor on the DVD review dataset, we will also be looking at a very small set of examples that illustrate cases of each of the extensions that we will be making.
#
# Run the following cell to load up these sentences.
# - Each example is a three tuple of the form
# `(<example_name>,<sentence>,<set of opinion words>)`

# %%
core = [("A.1","It has an exciting fresh plot.",set(["fresh", "exciting"])),
        ("B.1","The plot was dull.",set(["dull"])),
        ("C.1","It has an excessively dull plot.",set(["excessively-dull"])),
        ("C.2","The plot was excessively dull.",set(["excessively-dull"])),
        ("D.1","The plot wasn't dull.",set(["not-dull"])),
        ("D.2","It wasn't an exciting fresh plot.",set(["not-exciting", "not-fresh"])),
        ("D.3","The plot wasn't excessively dull.",set(["not-excessively-dull"])),
        ("E.1","The plot was cheesy, but fun and inspiring.",set(["cheesy", "fun", "inspiring"])),
        ("E.2","The plot was really cheesy and not particularly special.",set(["really-cheesy", "not-particularly-special"]))
       ]

optional = [("A","The script and plot are utterly excellent.",set(["utterly-excellent"])),
            ("B","The script and plot were unoriginal and boring.",set(["unoriginal", "boring"])),
            ("C","The plot wasn't lacking.",set(["not-lacking"])),
            ("D","The plot is full of holes.",set(["full-of-holes"])),
            ("E","There was no logical plot to this story.",set(["no-logical"])),
            ("F","I loved the plot.",set(["loved"])),
            ("G","I didn't mind the plot.",set(["not-mind"]))
           ]

# %% [markdown]
# ### Problem with displaCy
#
# You have been encouraged to use the dependency tree visualisation tool found [here](https://demos.explosion.ai/displacy).
#
# However, it turns out that what it says on the displaCy site is incorrect, and the displaCy visualiser uses a *different* parsing model from the one that is installed by default with spaCy, and as a result, there are cases where the trees are different.
#
# It is possible to set up spaCy to use the same model as displaCy by doing the following:
#
# ```
# import spacy
# nlp = spacy.load('en')
# python -m spacy download en_core_web_md
# nlp2 = spacy.load('en_core_web_md')
# ```
#
# However, I would recommend that you stick with the spaCy default model, and check for differences. In the cell below, you will find code that can be used to show the structure of the dependency tree produced by spaCy, and it shows an example where the tree differs from that shown by the displaCy visualiser.

# %%
def print_dep_tree(node,indent):
    print(indent,node)
    indent = indent + "  "
    for child in node.children:
        print_dep_tree(child,indent)

sent = "He is a complete idiot"   
parsed_sents = nlp(sent)
parsed_sent = next(parsed_sents.sents)
print_dep_tree(parsed_sent.root,"")
# Out:
#  is
#    He
#    idiot
#      a
#      complete

# %% [markdown]
# ## Extension A: Adjectival modification
# In this section, we are interested in adjectival modification. This is when we have a noun like "*dog*" or "*plot*", and there are one or more adjectives which are specifying the characteristics of that noun. E.g. "*big brown dog*" or "*exciting fresh plot*" ("*big*" and "*brown*" are both adjectivally modifying "*dog*").
#
# The dependency relation we use to show this relationship is `amod`.
#
# Write a version of the opinion extraction function which, when given sentences such as the example below containing an aspects token (e.g. "*plot*"), uses the `amod` relations to extract a list of the adjectival modifiers of the aspect token (e.g. the two words "*exciting*" and "*fresh*" in this case).
#
# **Core Example A.1**: "*It has an exciting fresh plot.*" should produce "*fresh*", "*exciting*"
#
# The dependency trees for this sentence is shown below.

# %% [markdown]
# ![Extension 1 example](./img/amod_example.png)

# %% [markdown]
# ### Exercise
# Adapt your opinion extractor so that it just finds adjectival modifiers, and apply it to examples test set in order to check that your function is working as required.
# - Note, your opinion extractor should only get the first example, A.1, correct.
#
# Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "*plot*", "*characters*", "*cinematography*", and "*dialogue*".

# %%
def opinion_extractor(aspect_token, parsed_sentence):
    opinions = list()
    for token in parsed_sentence:
        if token.pos_ == 'NOUN' and token.orth_ == aspect_token:
            for child in token.children:
                if child.pos_ == 'ADJ' and child.dep_ == 'amod':
                        opinions.append(child.orth_)
    return opinions

aspect_words = ["plot","characters","cinematography","dialogue"]
sentence = "It has an exciting fresh plot."
parsed_sent = nlp(sentence)

for word in aspect_words:
    if word in sentence:
        print("Results for word '{}'".format(word))
        print("\tSentence: {}".format(sentence))
        print("\t",*opinion_extractor(word, parsed_sent))
# Out:
# Results for word 'plot'
# 	Sentence: It has an exciting fresh plot.
# 	 exciting fresh

# %% [markdown]
# ## Extension B: Adjectives linked by copulae
# In this section, we are interested in adjectives which are linked to our aspect term via the copula (conjugations of "*to be*": "*is*", "*was*", "*will be*", etc.).
#
# Notice that if we were only looking for `amod` relations, we'd completely miss the word "*dull*" in the dependency tree shown below.
#
# Your opinion extraction function when given a sentences like the example below containing the aspect token "*plot*", should use appropriate dependency relations to output the term opinion word "*dull*".
#
# **Core Example B.1**: "*The plot was dull.*" should produce "*dull*"
#
# The dependency trees for this sentence is shown below.

# %% [markdown]
# ![Extension 2 example](./img/copula_example.png)

# %% [markdown]
# ### Exercise
# Extend the opinion extractor as described above and apply it to examples test set in order to check that your function is working as required.
# - Your opinion extractor should now work on examples, A.1 and B.1
#
# Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "*plot*", "*characters*", "*cinematography*", and "*dialogue*".

# %%
def opinion_extractor(aspect_token, parsed_sentence):
    opinions = list()
    for token in parsed_sentence:
        if token.pos_ == 'NOUN' and token.orth_ == aspect_token:
            for child in token.children:
                if child.dep_ == 'amod':
                        opinions.append(child.orth_)
            if token.dep_ == 'nsubj':
                for child in token.head.children:
                    if child.dep_ == 'acomp':
                        opinions.append(child.orth_)
    return opinions

aspect_words = ["plot","characters","cinematography","dialogue"]
sentence = "The plot was dull." 
parsed_sent = nlp(sentence)

for word in aspect_words:
    if word in sentence:
        print("Results for word '{}'".format(word))
        print("\tSentence: {}".format(sentence))
        print("\t", opinion_extractor(word, parsed_sent))
# Out:
# Results for word 'plot'
# 	Sentence: The plot was dull.
# 	 ['dull']

# %% [markdown]
# ## Extension C: Adverbial modifiers
# If you used the extractor you have built so far on the example sentences below, it will only find the opinion "*dull*". It would not recover an indication of the strength of the opinion. Adverbs like "*excessively*" elaborate on the adjectives that they modify in adverbial modification relations.
#
# The relevant dependency relation we use to show this relationship is "*advmod*".
#
# Your opinion extraction function when given a sentence like those below containing the aspect token "*plot*", should use the `advmod` relation to output features like "*excessively-dull*"
# - If you have an adjective token in a variable `adj_token`, and an adverb in a variable `adv_token` then you could create this feature like this: `adv_token.form + "-" + adj_token.form`.
# - If you have a list of strings, you can use python's `join` function to concatenate them into a single string. The following would join the strings together, placing a `"-"` between each:
# `joined_string = "-".join(listofstrings)`
#
#
# **Core Example C.1**: "*It has an excessively dull plot.*" should produce "*excessively-dull*"
# **Core Example C.2**: "*The plot was excessively dull.*" should produce "*excessively-dull*"
#
# The dependency trees for these sentences are shown below.

# %% [markdown]
# ![Extension 3 example](./img/advmod_example_1.png)

# %% [markdown]
# ![Extension 3 example 2](./img/advmod_example_2.png)

# %% [markdown]
# ### Exercise
# Extend the opinion extractor as described above and apply it to examples test set in order to check that your function is working as required.
# - Your opinion extractor should now work on examples A.1, B.1, C.1, and C.2.
#
# Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "*plot*", "*characters*", "*cinematography*", and "*dialogue*".

# %%
def opinion_extractor(aspect_token, parsed_sentence):
    opinions = list()
    for token in parsed_sentence:
        if token.pos_ == 'NOUN' and token.orth_ == aspect_token:
            for child in token.children:
                if child.pos_ == 'ADJ' and child.dep_ == 'amod':
                    if list(child.children):
                        for sub_child in child.children:
                            if sub_child.pos_ == 'ADV' and sub_child.dep_ == 'advmod':
                                opinions.append(sub_child.orth_ + "-" + child.orth_)
                    else: 
                        opinions.append(child.orth_)
            if token.head.pos_ == 'VERB' and token.dep_ == 'nsubj':
                for child in token.head.children:
                    if child.pos_ == 'ADJ' and child.dep_ == 'acomp':
                        if list(child.children):
                            for sub_child in child.children:
                                if sub_child.pos_ == 'ADV' and sub_child.dep_ == 'advmod':
                                    opinions.append(sub_child.orth_ + "-" + child.orth_)
                        else: 
                            opinions.append(child.orth_)
    return opinions

aspect_words = ["plot","characters","cinematography","dialogue"]
sentence =  "The plot was excessively dramatically dull." 
parsed_sent = nlp(sentence)

for word in aspect_words:
    if word in sentence:
        print("Results for word '{}'".format(word))
        print("\tSentence: {}".format(sentence))
        print("\t", *opinion_extractor(word, parsed_sent))
# Out:
# Results for word 'plot'
# 	Sentence: The plot was excessively dramatically dull.
# 	 excessively-dull dramatically-dull

# %% [markdown]
# ## Extension D: Negation
# Look at the tree below; it is an example of an adjective linked by a copula. Your existing opinion extractor would extract "dull". However, notice that the example is saying that the plot was not dull! This is an example of the use of negation.
#
# The dependency relation we use to show this relationship is `neg`.
#
# Your opinion extraction function when given sentences like those below containing the aspect token "*plot*", should use the `neg` relation to output features like "*not-dull*". If you have an adjective token called `"token"`, then you could create this feature like this: `"not-" + token.form`.
#
# **Core Example D.1**: "*The plot wasn't dull.*" should produce "*not-dull*"
# **Core Example D.2**: "*It wasn't an exciting fresh plot.*" should produce "*not-exciting*", "*not-fresh*"
# **Core Example D.3**: "*The plot wasn't excessively dull.*" should produce "*not-excessively-dull*"
#
# The dependency trees for these sentences are shown below.

# %% [markdown]
# ![Extension 4 example 1](./img/negation_example_1.png)

# %% [markdown]
# ![Extension 4 example 2](./img/negation_example_2.png)

# %% [markdown]
# ![Extension 4 example 3](./img/negation_example_3.png)

# %% [markdown]
# ### Exercise
# Extend the opinion extractor as described above and apply it to examples test set in order to check that your function is working as required.
# - Your opinion extractor should now work on examples A.1, B.1, C.1, C.2, D.1, D.2, and D.3.
#
# Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "*plot*", "*characters*", "*cinematography*", and "*dialogue*".

# %%
def opinion_extractor(aspect_token, parsed_sentence):
    opinions = list()
    
    for token in parsed_sentence:
        if token.pos_ == 'NOUN' and token.orth_ == aspect_token:
            for child in token.children:
                if child.pos_ == 'ADJ' and child.dep_ == 'amod':
                    if has_advmod(child):
                        for sub_child in child.children:                        
                            if sub_child.pos_ == 'ADV' and sub_child.dep_ == 'advmod':
                                opinions.append(sub_child.orth_ + "-" + child.orth_)
                    elif has_neg(token):
                        for sub_child in token.children:                        
                            if sub_child.pos_ == 'ADV' and sub_child.dep_ == 'neg':
                                opinions.append("not-" + child.orth_)
                    else:
                        opinions.append(child.orth_)
            if token.head.pos_ == 'VERB' and token.dep_ == 'nsubj':
                for child in token.head.children:
                    if child.pos_ == 'ADJ' and child.dep_ == 'acomp':                        
                        if has_advmod(child):
                            for sub_child in child.children:                        
                                if sub_child.pos_ == 'ADV' and sub_child.dep_ == 'advmod':
                                    if has_neg(child):
                                        for sub_child_1 in child.children:
                                            if sub_child_1.pos_ == 'ADV' and sub_child_1.dep_ == 'neg':
                                                opinions.append("not-" + sub_child.orth_ + "-" + child.orth_)
                                    else:
                                        opinions.append(sub_child.orth_ + "-" + child.orth_)
                        elif has_neg(child): 
                            for sub_child in child.children:                        
                                if sub_child.pos_ == 'ADV' and sub_child.dep_ == 'neg':
                                    opinions.append("not-" + child.orth_)
                        else:
                            opinions.append(child.orth_)
                            
    return opinions

def has_advmod(token):
    for child in token.children:
        if child.pos_ == 'ADV' and child.dep_ == 'advmod':
            return True

def has_neg(token):
    for child in token.children:
        if child.pos_ == 'ADV' and child.dep_ == 'neg':
            return True

aspect_words = ["plot","characters","cinematography","dialogue"]                     
parsed_sent = nlp(sentence)
for doc in core:
    for word in aspect_words:
        if word in sentence:
            print("Results for word '{}'".format(word))
            print("\tSentence: {}".format(doc[1]))
            print("\t", opinion_extractor(word, nlp(doc[1])))
            print("--------------------------------------------------------------------------------------------")
# Out:
# Results for word 'plot'
# 	Sentence: It has an exciting fresh plot.
# 	 ['exciting', 'fresh']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: The plot was dull.
# 	 ['dull']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: It has an excessively dull plot.
# 	 ['excessively-dull']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: The plot was excessively dull.
# 	 ['excessively-dull']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: The plot wasn't dull.
# 	 ['not-dull']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: It wasn't an exciting fresh plot.
# 	 ['not-exciting', 'not-fresh']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: The plot wasn't excessively dull.
# 	 ['not-excessively-dull']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: The plot was cheesy, but fun and inspiring.
# 	 ['cheesy']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: The plot was really cheesy and not particularly special.
# 	 ['really-cheesy']
# --------------------------------------------------------------------------------------------

# %% [markdown]
# ## Extension E: Conjunction
# If you used your existing extractor on the tree below, it would only extract "*cheesy*". However, "*fun*" and "*inspiring*" are both conjoined with "*cheesy*"; this means that they all apply to the subject ("*plot*").
#
# This conjunction relation is shown via the `conj` dependency. Note that words other than adjectives can be the conjuncts. You could investigate whether this is a problem.
#
# **Core Example E.1**: "*The plot was cheesy but fun and inspiring.*" should produce "*cheesy*", "*fun*", "*inspiring*"
# **Core Example E.2**: "*The plot was really cheesy and not particularly special.*" should produce "*really-cheesy*", "*not-particularly-special*"
#
# The dependency trees for these sentences are shown below.

# %% [markdown]
# ![Extension 5 example](./img/conj_example_1.png)

# %% [markdown]
# ![Extension 5 example 2](./img/conj_example_2.png)

# %% [markdown]
# ### Exercise
# Extend the opinion extractor as described above and apply it to examples test set in order to check that your function is working as required.
# - Your opinion extractor should now work on all of the required examples.
#
# Investigate the extent to which your opinion extractor produces appropriate opinion bearing words by applying it to the full set of parsed DVD reviews. Consider all four aspects: "*plot*", "*characters*", "*cinematography*", and "*dialogue*".

# %%
core = [("A.1","It has an exciting fresh plot.",set(["fresh", "exciting"])),
        ("B.1","The plot was dull.",set(["dull"])),
        ("C.1","It has an excessively dull plot.",set(["excessively-dull"])),
        ("C.2","The plot was excessively dull.",set(["excessively-dull"])),
        ("D.1","The plot wasn't dull.",set(["not-dull"])),
        ("D.2","It wasn't an exciting fresh plot.",set(["not-exciting", "not-fresh"])),
        ("D.3","The plot wasn't excessively dull.",set(["not-excessively-dull"])),
        ("E.1","The plot was cheesy but fun and inspiring.",set(["cheesy", "fun", "inspiring"])),
        ("E.2","The plot was really cheesy and not particularly special.",set(["really-cheesy", "not-particularly-special"]))
       ]

optional = [("A","The script and plot are utterly excellent.",set(["utterly-excellent"])),
            ("B","The script and plot were unoriginal and boring.",set(["unoriginal", "boring"])),
            ("C","The plot wasn't lacking.",set(["not-lacking"])),
            ("D","The plot is full of holes.",set(["full-of-holes"])),
            ("E","There was no logical plot to this story.",set(["no-logical"])),
            ("F","I loved the plot.",set(["loved"])),
            ("G","I didn't mind the plot.",set(["not-mind"]))
           ]

# %%
def print_dep_tree(node,indent):
    print(indent,node)
    indent = indent + "  "
    for child in node.children:
        print_dep_tree(child,indent)

sent = "It wasn't an exciting fresh plot."
parsed_sents = nlp(sent)
parsed_sent = next(parsed_sents.sents)
print_dep_tree(parsed_sent.root,"")
# Out:
#  was
#    It
#    plot
#      n't
#      an
#      exciting
#      fresh
#    .

# %%
def opinion_extractor(aspect_token, parsed_sentence):
    opinions = list()
    for token in parsed_sentence:
        if token.pos_ == 'NOUN' and token.orth_ == aspect_token:
            opinion_extractor(aspect_token, [t for t in token.subtree if not t == token])
        if noun_relation(token, aspect_token):
            if (token.dep_ == 'acomp' or token.dep_ == 'amod' or token.dep_ == 'conj'):
                if has_advmod(token):
                    opinion_extractor(aspect_token, [t for t in token.subtree if not t == token])
                else:
                    opinions.append(is_neg(token) + token.orth_) 
            elif token.dep_ == 'advmod':
                opinions.append(is_neg(token) + token.orth_ + "-" + token.head.orth_)
    return opinions

def noun_relation(token, ancestor):
    for anc in token.ancestors:
        if anc.orth_ == ancestor:
            return True
        elif anc.pos_ == 'VERB':
            for kid in anc.children:
                if kid.orth_ == ancestor:
                    return True

def is_neg(token):
    if has_neg(token) or has_neg(token.head):
        return "not-"
    return ""

def has_neg(token):
    for child in token.children:
        if child.dep_ == 'neg':
            return True
        
def has_advmod(token):
    for child in token.children:
        if child.dep_ == 'advmod':
            return True

aspect_words = ["plot","characters","cinematography","dialogue"]
extensions = [doc[0] for doc in core]
sentences = [doc[1] for doc in core]
expected = [doc[2] for doc in core]
opinions = [[opinion_extractor(word, nlp(doc[1])) for word in aspect_words if word in doc[1]] for doc in core]

#df = pd.DataFrame(list(zip(extensions, sentences, expected, opinions)), columns = ["Extension", "Sentence", "Expected", "Opinion"])
#display(df)
for doc in core:
    for word in aspect_words:
        if word in doc[1]:
            print("Results for word '{}'".format(word))
            print("\tSentence: {}".format(doc[1]))
            print("\t", opinion_extractor(word, nlp(doc[1])))
            print("--------------------------------------------------------------------------------------------")
# Out:
# Results for word 'plot'
# 	Sentence: It has an exciting fresh plot.
# 	 ['exciting', 'fresh']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: The plot was dull.
# 	 ['dull']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: It has an excessively dull plot.
# 	 ['excessively-dull']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: The plot was excessively dull.
# 	 ['excessively-dull']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: The plot wasn't dull.
# 	 ['not-dull']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: It wasn't an exciting fresh plot.
# 	 ['not-exciting', 'not-fresh']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: The plot wasn't excessively dull.
# 	 ['not-excessively-dull']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: The plot was cheesy but fun and inspiring.
# 	 ['cheesy', 'fun', 'inspiring']
# --------------------------------------------------------------------------------------------
# Results for word 'plot'
# 	Sentence: The plot was really cheesy and not particularly special.
# 	 ['really-cheesy', 'not-particularly-special']
# --------------------------------------------------------------------------------------------

# %% [markdown]
# ## Additional extensions

# %% [markdown]
# This section presents some examples on which your current opinion extractor will fail. In all of the examples below, "plot" is the aspect token.
#
# You are not required to extend your opinion extractor to handle these cases.
#
# **Optional Example A**: "The script and plot are utterly excellent." produces "utterly-excellent"
# **Optional Example B**: "The script and plot were unoriginal and boring." produces "unoriginal", "boring"
# **Optional Example C**: "The plot wasn't lacking." produces "not-lacking"
# **Optional Example D**: "The plot is full of holes." produces "full-of-holes"
# **Optional Example E**: "There was no logical plot to this story." produces "no-logical"
# **Optional Example F**: "I loved the plot." produces "loved"
# **Optional Example G**: "I didn't mind the plot." produces "not-mind"
#
# The dependency trees for these sentences are shown below.

# %% [markdown]
# ![Extension example 2](./img/additional_example_1.png)

# %% [markdown]
# ![Extension example 2](./img/additional_example_2.png)

# %% [markdown]
# ![Extension example 2](./img/additional_example_3.png)

# %% [markdown]
# ![Extension example 2](./img/additional_example_4.png)

# %% [markdown]
# ![Extension example 2](./img/additional_example_5.png)

# %% [markdown]
# ![Extension example 2](./img/additional_example_6.png)

# %% [markdown]
# ![Extension example 2](./img/additional_example_7.png)

# %% [markdown]
# ## Tips for de-bugging and exploration
# When you will be assessing whether your opinion extractor has been effective when analysing a given sentence. Before you look at what the dependency parser says, read the sentence carefully and determine for yourself the scope of the words. Consider the following sentence.
#
# "This film has excellent characters and an intriguing and engaging plot."
#
# It should be obvious to you that here the plot is described as both "intriguing" and "engaging". However, "excellent" is only used to describe the cinematography.
#
# If the parser suggests a structure which implies that plot is also described by "excellent" (for example), something has gone wrong.### Dependency tree visualisation tool
# You may find it useful to use the dependency tree visualisation tool found [here](https://demos.explosion.ai/displacy).
#
# You can copy and past example sentences from the DVD review data to get a good sense of what the dependency parse looks like.
#
# ### Outputing results only from sentences relevant to the current task
# You will find that your output is dominated by examples of adjectival modification and adjectives linked via the copula. This means that when you add a new function (extensions 3-5) it will be difficult to determine the impact of that new functionality.
#
# One way to solve this problem, is to (temporarily) output only those features produced by the new functionality.
#
# For example, imagine you have just completed extensions 1 and 2. Next, you write code that adds the adverbial features (extension 3). When assessing how well your code is working, let your extractor only extract the "new" adverb features.
#
# There are 2 easy ways to achieve this:
#
# 1. Comment out any extractor code that produces features that you're not currently interested in. Or
# 2. Introduce a boolean variable, which you only set to `True` when you have extracted the feature that you are interested in. Then always ouput an empty list if the variable is `False`, otherwise output the full opinion list.
